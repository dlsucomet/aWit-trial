# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import regex as re

# %%
musicBg = pd.read_csv('musicBg.csv')

musicBg.head()
# Out:
#                          Email Address Student?          Age Range  \
# 0         alyssandra_lemen@dlsu.edu.ph      Yes  18 - 27 years old
# 1         hershel_judd_lee@dlsu.edu.ph      Yes  18 - 27 years old
# 2               jan_dacera@dlsu.edu.ph      Yes  18 - 27 years old
# 3        nicolle_kendra_uy@dlsu.edu.ph      Yes  18 - 27 years old
# 4  matthew_joshua_d_garcia@dlsu.edu.ph      Yes  18 - 27 years old
#
#   Current Residence  Duration of PH Residence  Music is important to me  \
# 0        Davao City                        20                         7
# 1    Bacoor, Cavite                        18                         4
# 2    Bacoor, Cavite                        19                         7
# 3            Manila                        21                         5
# 4       Quezon City                        21                         7
#
#   Years of Music Experience?  Genre[Alternative]  Genre[Blues]  \
# ...

# %%
crowdsource_pd = pd.read_csv('crowdsource_pd.csv')

crowdsource_pd.head()
# Out:
#    Unnamed: 0                                          Song Name  \
# 0           0                                          Kill Bill
# 1           1  Until I Found You (with Em Beihold) - Em Beiho...
# 2           2                                          THE SHADE
# 3           3                                      Glimpse of Us
# 4           4                                                OMG
#
#                    Artist Name  \
# 0                          SZA
# 1  Stephen Sanchez, Em Beihold
# 2            Rex Orange County
# 3                         Joji
# 4                     NewJeans
#
#                                     Song Familiarity  \
# 0  [6, 6, 5, 7, 7, 5, 5, 1, 6, 2, 2, 7, 4, 7, 1, ...
# 1  [7, 6, 6, 7, 7, 6, 7, 6, 7, 7, 5, 5, 7, 6, 7, ...
# 2  [7, 5, 5, 5, 6, 1, 1, 6, 5, 1, 2, 5, 7, 6, 6, ...
# 3  [7, 3, 1, 7, 7, 7, 1, 6, 6, 7, 2, 7, 7, 7, 6, ...
# 4  [7, 7, 1, 7, 5, 6, 6, 6, 1, 7, 1, 7, 7, 7, 1, ...
#
# ...

# %%
set_emails_pd = pd.read_csv('set_emails_pd.csv')

set_emails_pd.head()
# Out:
#   Set                                    Email Addresses  \
# 0   A  ['alyssandra_lemen@dlsu.edu.ph', 'nehro_ranay@...
# 1   B  ['hershel_judd_lee@dlsu.edu.ph', 'pat_ang@dlsu...
# 2   C  ['james_lin@dlsu.edu.ph', 'jan_dacera@dlsu.edu...
# 3   D  ['romiane_gonzales@dlsu.edu.ph', 'tmata96@gmai...
# 4   E  ['hylene_jules_lee@dlsu.edu.ph', 'matthew_josh...
#
#                                            Timestamp
# 0  ['2/1/2023 8:37:00', '2/1/2023 11:06:17', '2/6...
# 1  ['1/31/2023 10:15:38', '2/4/2023 10:12:55', '2...
# 2  ['1/31/2023 12:01:45', '1/31/2023 19:39:48', '...
# 3  ['1/31/2023 16:42:11', '2/2/2023 12:50:08', '2...
# 4  ['1/31/2023 9:33:05', '2/1/2023 16:28:06', '2/...
