# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
intrinsic = pd.read_csv('ThesisHits.csv')
intrinsic
# Out:
#     Unnamed: 0                                              title  \
# 0            0                                          Kill Bill
# 1            1                                             Mahika
# 2            2                                          Anti-Hero
# 3            3                                       Here With Me
# 4            4                                              Ditto
# 5            5                                      Made You Look
# 6            6                       Wet The Bed (feat. Ludacris)
# 7            7                          Unholy (feat. Kim Petras)
# 8            8                                Under The Influence
# 9            9            Babalik Sa'yo (from "2 Good 2 Be True")
# 10          10  Until I Found You (with Em Beihold) - Em Beiho...
# 11          11                                      Midnight Rain
# 12          12                                             Umaasa
# ...

# %%
crowdsource = pd.read_csv('crowdsource_pd_final.csv')
crowdsource
# Out:
#     Unnamed: 0                                          Song Name  \
# 0            0                                          Kill Bill
# 1            1  Until I Found You (with Em Beihold) - Em Beiho...
# 2            2                                          THE SHADE
# 3            3                                      Glimpse of Us
# 4            4                                                OMG
# 5            5                                             Mahika
# 6            6                                      Midnight Rain
# 7            7                                           Isa lang
# 8            8                                   I Wanna Be Yours
# 9            9                                              Yakap
# 10          10                                          Anti-Hero
# 11          11                                             Umaasa
# 12          12            Left and Right (Feat. Jung Kook of BTS)
# ...

# %%
musicBg = pd.read_csv('musicBg.csv')
musicBg
# Out:
#                            Email Address Student?          Age Range  \
# 0           alyssandra_lemen@dlsu.edu.ph      Yes  18 - 27 years old
# 1           hershel_judd_lee@dlsu.edu.ph      Yes  18 - 27 years old
# 2                 jan_dacera@dlsu.edu.ph      Yes  18 - 27 years old
# 3          nicolle_kendra_uy@dlsu.edu.ph      Yes  18 - 27 years old
# 4    matthew_joshua_d_garcia@dlsu.edu.ph      Yes  18 - 27 years old
# ..                                   ...      ...                ...
# 195             drei_gaurana@dlsu.edu.ph      Yes  18 - 27 years old
# 196            kasey_m_subia@dlsu.edu.ph      Yes  18 - 27 years old
# 197              wesley_chua@dlsu.edu.ph      Yes  18 - 27 years old
# 198               bertnocete09@gmail.com      Yes  18 - 27 years old
# 199    eryn_gabriel_tallador@dlsu.edu.ph      Yes  18 - 27 years old
#
#        Current Residence  Duration of PH Residence  Music is important to me  \
# ...

# %%
# make sure same index!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
merged = pd.concat([intrinsic, crowdsource], axis=1)
merged
# Out:
#     Unnamed: 0                                              title  \
# 0            0                                          Kill Bill
# 1            1                                             Mahika
# 2            2                                          Anti-Hero
# 3            3                                       Here With Me
# 4            4                                              Ditto
# 5            5                                      Made You Look
# 6            6                       Wet The Bed (feat. Ludacris)
# 7            7                          Unholy (feat. Kim Petras)
# 8            8                                Under The Influence
# 9            9            Babalik Sa'yo (from "2 Good 2 Be True")
# 10          10  Until I Found You (with Em Beihold) - Em Beiho...
# 11          11                                      Midnight Rain
# 12          12                                             Umaasa
# ...

# %%
## check the intrinsic summary stats of those rated below average and above average per AR&NR

# %%
low_count = merged[['title', 'artist/s']]
up_count = merged[['title', 'artist/s']]
# low_count['count'] = 0
# up_count['count'] = 0

# %%
lowCtr = [0] * 50
upCtr = [0] * 50

# %%
avg = merged['AR[bad-good]'].mean()
low = merged[merged['AR[bad-good]'] < avg]
up = merged[merged['AR[bad-good]'] >= avg]
avg
# Out:
# 5.517000000000001

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.569300       0.54500      0.127669       0.3480
# 1      loudness      -7.282450      -6.23750      2.930432     -13.8500
# 2   speechiness       0.059315       0.04685      0.044452       0.0283
# 3      liveness       0.171950       0.14750      0.078636       0.0846
# 4       valence       0.385550       0.35050      0.190988       0.1080
# 5         tempo     121.874200     120.60100     26.644886      81.0010
# 6      duration  224001.800000  210463.50000  48889.383959  153947.0000
#
#       Maximum
# 0       0.874
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.783
# 5     173.930
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.652500       0.64050      0.150126       0.3580
# 1      loudness      -7.421367      -7.40550      2.170945     -11.1410
# 2   speechiness       0.050033       0.04175      0.023977       0.0232
# 3      liveness       0.144623       0.12050      0.068472       0.0771
# 4       valence       0.457500       0.41300      0.207961       0.1720
# 5         tempo     116.017433     116.92400     27.986016      60.0010
# 6      duration  211093.966667  201248.50000  44957.448172  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.884
# 5     174.839
# 6  335625.000

# %%
avg = merged['AR[distasteful-tasty]'].mean()
low = merged[merged['AR[distasteful-tasty]'] < avg]
up = merged[merged['AR[distasteful-tasty]'] >= avg]
avg
# Out:
# 5.339000000000001

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.549294       0.5390      0.107047       0.3480
# 1      loudness      -7.269941      -6.4250      2.728082     -13.8500
# 2   speechiness       0.056918       0.0396      0.047752       0.0283
# 3      liveness       0.184300       0.1740      0.079100       0.0846
# 4       valence       0.375000       0.3590      0.181626       0.1080
# 5         tempo     120.096000     120.0320     28.089009      81.0010
# 6      duration  222995.470588  209260.0000  48907.200461  153947.0000
#
#       Maximum
# 0       0.710
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.783
# 5     173.930
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.655242       0.6430      0.151766       0.3580
# 1      loudness      -7.415182      -7.4050      2.376672     -11.7380
# 2   speechiness       0.052112       0.0433      0.024048       0.0232
# 3      liveness       0.140745       0.1130      0.066384       0.0771
# 4       valence       0.456394       0.4110      0.209704       0.1720
# 5         tempo     117.465909     119.8690     27.336145      60.0010
# 6      duration  212785.818182  201807.0000  45616.073206  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.884
# 5     174.839
# 6  335625.000

# %%
avg = merged['AR[dull-exciting]'].mean()
low = merged[merged['AR[dull-exciting]'] < avg]
up = merged[merged['AR[dull-exciting]'] >= avg]
avg
# Out:
# 5.049

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.575478       0.5510      0.138527       0.3580
# 1      loudness      -7.542565      -7.1630      2.596609     -13.8500
# 2   speechiness       0.046530       0.0358      0.020388       0.0254
# 3      liveness       0.163361       0.1380      0.071401       0.0771
# 4       valence       0.385261       0.3490      0.186635       0.1080
# 5         tempo     121.821565     120.0320     29.113715      72.4980
# 6      duration  217135.956522  209260.0000  48006.622287  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.562
# 2       0.100
# 3       0.315
# 4       0.884
# 5     174.839
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.656481       0.6440      0.144473       0.3480
# 1      loudness      -7.215222      -7.3750      2.405176     -11.1680
# 2   speechiness       0.059893       0.0452      0.041085       0.0232
# 3      liveness       0.148904       0.1130      0.075360       0.0822
# 4       valence       0.465741       0.4790      0.211461       0.1720
# 5         tempo     115.411519     113.9790     25.911282      60.0010
# 6      duration  215508.444444  201807.0000  46115.122796  154487.0000
#
#       Maximum
# 0       0.882
# 1      -3.299
# 2       0.225
# 3       0.332
# 4       0.824
# 5     169.914
# 6  335625.000

# %%
avg = merged['AR[tasteless-tasteful]'].mean()
low = merged[merged['AR[tasteless-tasteful]'] < avg]
up = merged[merged['AR[tasteless-tasteful]'] >= avg]
avg
# Out:
# 5.317

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.586000       0.56050      0.146223       0.3480
# 1      loudness      -7.139667      -6.23750      2.865551     -13.8500
# 2   speechiness       0.060789       0.04685      0.046193       0.0283
# 3      liveness       0.172006       0.14750      0.083167       0.0771
# 4       valence       0.430111       0.38950      0.226059       0.1080
# 5         tempo     122.077222     120.60100     27.418639      81.0010
# 6      duration  220725.833333  210463.50000  51009.510818  134256.0000
#
#       Maximum
# 0       0.874
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.884
# 5     173.930
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.637906       0.63600      0.145006       0.3580
# 1      loudness      -7.493000      -7.40550      2.265008     -11.7380
# 2   speechiness       0.049784       0.04175      0.023813       0.0232
# 3      liveness       0.146300       0.12150      0.066531       0.0822
# 4       valence       0.427938       0.35450      0.191814       0.1720
# 5         tempo     116.269281     116.92400     27.500781      60.0010
# 6      duration  213743.437500  201248.50000  44443.318712  154487.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.824
# 5     174.839
# 6  335625.000

# %%
avg = merged['AR[unimaginative-creative]'].mean()
low = merged[merged['AR[unimaginative-creative]'] < avg]
up = merged[merged['AR[unimaginative-creative]'] >= avg]
avg
# Out:
# 5.261

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.587250       0.5665      0.147543       0.3580
# 1      loudness      -7.493917      -7.0905      2.779373     -13.8500
# 2   speechiness       0.058683       0.0497      0.040780       0.0283
# 3      liveness       0.179375       0.1775      0.081591       0.0771
# 4       valence       0.425208       0.3895      0.227643       0.1080
# 5         tempo     125.852917     120.6010     27.854543      88.9930
# 6      duration  212459.000000  207344.0000  46723.001179  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.430
# 2       0.225
# 3       0.330
# 4       0.884
# 5     174.839
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.648731       0.64050      0.141208       0.3480
# 1      loudness      -7.247538      -7.39000      2.205803     -11.0910
# 2   speechiness       0.049188       0.04035      0.025198       0.0232
# 3      liveness       0.133565       0.11050      0.057658       0.0879
# 4       valence       0.431962       0.35450      0.180766       0.1830
# 5         tempo     111.443731     115.48550     25.438296      60.0010
# 6      duration  219763.038462  201879.00000  46968.463907  154487.0000
#
#       Maximum
# 0       0.882
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.824
# 5     169.914
# 6  335625.000

# %%
avg = merged['AR[untalented-talented]'].mean()
low = merged[merged['AR[untalented-talented]'] < avg]
up = merged[merged['AR[untalented-talented]'] >= avg]
avg
# Out:
# 5.645999999999999

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.579381       0.5930      0.133127       0.3480
# 1      loudness      -7.766524      -7.1630      2.785261     -13.8500
# 2   speechiness       0.057195       0.0401      0.043912       0.0283
# 3      liveness       0.163152       0.1340      0.072847       0.0846
# 4       valence       0.396762       0.3590      0.183555       0.1080
# 5         tempo     118.541429     120.0320     29.426273      60.0010
# 6      duration  221634.714286  205428.0000  49203.386766  153947.0000
#
#       Maximum
# 0       0.874
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.783
# 5     173.930
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.648069       0.6350      0.150526       0.3750
# 1      loudness      -7.075621      -7.3750      2.228886     -11.1410
# 2   speechiness       0.051248       0.0433      0.024093       0.0232
# 3      liveness       0.150052       0.1280      0.074208       0.0771
# 4       valence       0.451862       0.4110      0.215352       0.1540
# 5         tempo     118.228862     119.8690     26.250622      67.5280
# 6      duration  212362.965517  201951.0000  44944.442110  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.884
# 5     174.839
# 6  335625.000

# %%
avg = merged['AR[unpleasant-pleasant]'].mean()
low = merged[merged['AR[unpleasant-pleasant]'] < avg]
up = merged[merged['AR[unpleasant-pleasant]'] >= avg]
avg
# Out:
# 5.6469999999999985

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.565800       0.5820      0.118565       0.3480
# 1      loudness      -7.520333      -6.4250      3.002786     -13.8500
# 2   speechiness       0.060773       0.0396      0.050521       0.0283
# 3      liveness       0.162540       0.1340      0.071557       0.0846
# 4       valence       0.367333       0.3590      0.169768       0.1080
# 5         tempo     116.569200     116.9920     25.023421      81.0010
# 6      duration  227062.200000  209260.0000  50189.276324  153947.0000
#
#       Maximum
# 0       0.733
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.783
# 5     171.883
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.642114       0.6350      0.152276       0.3580
# 1      loudness      -7.299571      -7.3790      2.257823     -11.1680
# 2   speechiness       0.050734       0.0433      0.023300       0.0232
# 3      liveness       0.152560       0.1280      0.074692       0.0771
# 4       valence       0.455029       0.4110      0.211794       0.1540
# 5         tempo     119.127686     120.0090     28.583640      60.0010
# 6      duration  211626.342857  201807.0000  44806.553315  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.884
# 5     174.839
# 6  335625.000

# %%
avg = merged['AR[forgettable-memorable]'].mean()
low = merged[merged['AR[forgettable-memorable]'] < avg]
up = merged[merged['AR[forgettable-memorable]'] >= avg]
avg
# Out:
# 5.166

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.620591       0.64350      0.162408       0.3580
# 1      loudness      -7.477364      -7.26900      2.583233     -13.8500
# 2   speechiness       0.051227       0.03735      0.024637       0.0283
# 3      liveness       0.151686       0.13050      0.065841       0.0771
# 4       valence       0.407045       0.36700      0.192922       0.1080
# 5         tempo     116.536682     118.43050     27.982516      60.0010
# 6      duration  212456.363636  189993.00000  53284.423170  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.562
# 2       0.102
# 3       0.315
# 4       0.884
# 5     174.839
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.618143       0.59650      0.135040       0.3480
# 1      loudness      -7.278143      -6.97500      2.430104     -11.1680
# 2   speechiness       0.055725       0.04425      0.039559       0.0232
# 3      liveness       0.158593       0.13300      0.079533       0.0822
# 4       valence       0.445750       0.38200      0.211635       0.1540
# 5         tempo     119.792857     121.47650     27.243685      67.5280
# 6      duration  219243.392857  211960.00000  41201.974599  167303.0000
#
#       Maximum
# 0       0.882
# 1      -3.299
# 2       0.225
# 3       0.332
# 4       0.824
# 5     173.930
# 6  335625.000

# %%
avg = merged['AR[boring-interesting]'].mean()
low = merged[merged['AR[boring-interesting]'] < avg]
up = merged[merged['AR[boring-interesting]'] >= avg]
avg
# Out:
# 5.197999999999999

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat          Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.56350       0.54500      0.127957       0.3580
# 1      loudness      -7.54125      -7.09050      2.773784     -13.8500
# 2   speechiness       0.05692       0.04115      0.044026       0.0283
# 3      liveness       0.19181       0.18300      0.074217       0.0846
# 4       valence       0.36075       0.32600      0.184587       0.1080
# 5         tempo     124.44490     118.51200     26.699443      90.1210
# 6      duration  214062.85000  195020.50000  47842.840411  156943.0000
#
#       Maximum
# 0       0.813
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.783
# 5     174.839
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.656367       0.6405      0.147598       0.3480
# 1      loudness      -7.248833      -7.4055      2.295874     -11.1680
# 2   speechiness       0.051630       0.0431      0.024972       0.0232
# 3      liveness       0.131383       0.1075      0.062682       0.0771
# 4       valence       0.474033       0.4545      0.204096       0.1720
# 5         tempo     114.303633     119.9390     27.439888      60.0010
# 6      duration  217719.933333  207102.0000  46377.871616  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.884
# 5     169.914
# 6  335625.000

# %%
avg = merged['NR[listen to similar songs]'].mean()
low = merged[merged['NR[listen to similar songs]'] < avg]
up = merged[merged['NR[listen to similar songs]'] >= avg]
avg
# Out:
# 5.036000000000001

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.599150       0.5875      0.142689       0.3480
# 1      loudness      -7.280150      -6.7940      2.860020     -13.8500
# 2   speechiness       0.059075       0.0414      0.044762       0.0283
# 3      liveness       0.165715       0.1305      0.077709       0.0771
# 4       valence       0.383200       0.3260      0.213061       0.1080
# 5         tempo     120.636300     120.6010     23.233655      81.0010
# 6      duration  213737.750000  200400.5000  50998.383438  134256.0000
#
#       Maximum
# 0       0.881
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.884
# 5     171.883
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.632600       0.6310      0.149260       0.3580
# 1      loudness      -7.422900      -7.4055      2.231520     -11.1680
# 2   speechiness       0.050193       0.0431      0.023660       0.0232
# 3      liveness       0.148780       0.1330      0.070524       0.0822
# 4       valence       0.459067       0.4225      0.192783       0.1720
# 5         tempo     116.842700     116.9240     30.048821      60.0010
# 6      duration  217936.666667  207102.0000  44099.873181  153947.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.824
# 5     174.839
# 6  335625.000

# %%
avg = merged['NR[share to my friends]'].mean()
low = merged[merged['NR[share to my friends]'] < avg]
up = merged[merged['NR[share to my friends]'] >= avg]
avg
# Out:
# 4.569

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.568389       0.56650      0.110692       0.3480
# 1      loudness      -7.426167      -6.79400      2.934113     -13.8500
# 2   speechiness       0.060289       0.04035      0.046838       0.0283
# 3      liveness       0.178394       0.16050      0.077020       0.0846
# 4       valence       0.381889       0.35050      0.183509       0.1080
# 5         tempo     120.772167     120.60100     26.432574      81.0010
# 6      duration  219935.666667  203617.50000  48714.294224  156943.0000
#
#       Maximum
# 0       0.714
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.783
# 5     173.930
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean       Median  Standard Dev      Minimum  \
# 0  danceability       0.647812       0.6360      0.157130       0.3580
# 1      loudness      -7.331844      -7.3920      2.226049     -11.1680
# 2   speechiness       0.050066       0.0431      0.023245       0.0232
# 3      liveness       0.142706       0.1105      0.068837       0.0771
# 4       valence       0.455063       0.4130      0.210621       0.1540
# 5         tempo     117.003375     118.4305     28.154391      60.0010
# 6      duration  214187.906250  206809.0000  45897.367407  134256.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.884
# 5     174.839
# 6  335625.000

# %%
avg = merged['NR[add to my playlist]'].mean()
low = merged[merged['NR[add to my playlist]'] < avg]
up = merged[merged['NR[add to my playlist]'] >= avg]
avg
# Out:
# 4.657

# %%
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(low['title'], low['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            lowCtr[i] = lowCtr[i] + 1

            
i=-1
for row1title, row1artist in zip(merged['title'], merged['artist/s']):
    i = i+1
    for row2title, row2artist in zip(up['title'], up['artist/s']):
        if (row1title == row2title) and (row1artist == row2artist):
            upCtr[i] = upCtr[i] + 1

# %%
low_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
low_mean = [low["danceability"].mean(), low["loudness"].mean(), low["speechiness"].mean(), low["liveness"].mean(), low["valence"].mean(), low["tempo"].mean(), low["duration_ms"].mean()]
low_median = [low["danceability"].median(), low["loudness"].median(), low["speechiness"].median(), low["liveness"].median(), low["valence"].median(), low["tempo"].median(), low["duration_ms"].median()]
low_min = [low["danceability"].min(), low["loudness"].min(), low["speechiness"].min(), low["liveness"].min(), low["valence"].min(), low["tempo"].min(), low["duration_ms"].min()]
low_max = [low["danceability"].max(), low["loudness"].max(), low["speechiness"].max(), low["liveness"].max(), low["valence"].max(), low["tempo"].max(), low["duration_ms"].max()]
low_std = [low["danceability"].std(), low["loudness"].std(), low["speechiness"].std(), low["liveness"].std(), low["valence"].std(), low["tempo"].std(), low["duration_ms"].std()]

low_stats = {'Summary Stat':low_names, 'Mean':low_mean, 'Median':low_median, 'Standard Dev':low_std, 'Minimum':low_min, 'Maximum':low_max}
low = pd.DataFrame(low_stats)
low
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.584150       0.56650      0.142507       0.3480
# 1      loudness      -7.780100      -7.37700      2.908261     -13.8500
# 2   speechiness       0.062280       0.05205      0.044515       0.0283
# 3      liveness       0.167805       0.13750      0.076341       0.0771
# 4       valence       0.383250       0.32150      0.217782       0.1080
# 5         tempo     124.329550     124.51350     25.149043      81.0010
# 6      duration  219890.000000  210463.50000  48618.986097  134256.0000
#
#       Maximum
# 0       0.874
# 1      -3.430
# 2       0.225
# 3       0.315
# 4       0.884
# 5     171.883
# 6  312320.000

# %%
up_names = ["danceability", "loudness", "speechiness", "liveness", "valence", "tempo", "duration"]
up_mean = [up["danceability"].mean(), up["loudness"].mean(), up["speechiness"].mean(), up["liveness"].mean(), up["valence"].mean(), up["tempo"].mean(), up["duration_ms"].mean()]
up_median = [up["danceability"].median(), up["loudness"].median(), up["speechiness"].median(), up["liveness"].median(), up["valence"].median(), up["tempo"].median(), up["duration_ms"].median()]
up_min = [up["danceability"].min(), up["loudness"].min(), up["speechiness"].min(), up["liveness"].min(), up["valence"].min(), up["tempo"].min(), up["duration_ms"].min()]
up_max = [up["danceability"].max(), up["loudness"].max(), up["speechiness"].max(), up["liveness"].max(), up["valence"].max(), up["tempo"].max(), up["duration_ms"].max()]
up_std = [up["danceability"].std(), up["loudness"].std(), up["speechiness"].std(), up["liveness"].std(), up["valence"].std(), up["tempo"].std(), up["duration_ms"].std()]

up_stats = {'Summary Stat':up_names, 'Mean':up_mean, 'Median':up_median, 'Standard Dev':up_std, 'Minimum':up_min, 'Maximum':up_max}
up = pd.DataFrame(up_stats)
up
# Out:
#    Summary Stat           Mean        Median  Standard Dev      Minimum  \
# 0  danceability       0.642600       0.63600      0.146157       0.3580
# 1      loudness      -7.089600      -6.79450      2.146743     -11.1410
# 2   speechiness       0.048057       0.04165      0.022873       0.0232
# 3      liveness       0.147387       0.12050      0.071119       0.0822
# 4       valence       0.459033       0.42250      0.189309       0.1720
# 5         tempo     114.380533     112.01600     28.411482      60.0010
# 6      duration  213835.166667  201248.50000  45740.784313  153947.0000
#
#       Maximum
# 0       0.898
# 1      -3.299
# 2       0.111
# 3       0.332
# 4       0.824
# 5     174.839
# 6  335625.000

# %%
low_count['count'] = lowCtr
up_count['count'] = upCtr
# Out:
# C:\Users\angel\AppData\Local\Temp/ipykernel_6028/1623903691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_count['count'] = lowCtr
# C:\Users\angel\AppData\Local\Temp/ipykernel_6028/1623903691.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   up_count['count'] = upCtr

# %%
## what songs are usually rated below average? above average?

# %%
low_count.sort_values(['count'], ascending=[False])
# Out:
#                                                 title  \
# 24                                           Old Love
# 27                                          Paraluman
# 40                                  Until I Found You
# 19                                 Fall In Love Alone
# 35                                        golden hour
# 33                                            Tahanan
# 14                                        Die For You
# 30                                            Pasilyo
# 23                                           Isa lang
# 39                                           Hype Boy
# 38                                         Sure Thing
# 11                                      Midnight Rain
# 10  Until I Found You (with Em Beihold) - Em Beiho...
# 8                                 Under The Influence
# 15                                          As It Was
# 17                                              Jopay
# ...

# %%
up_count.sort_values(['count'], ascending=[False])
# Out:
#                                                 title  \
# 16                                          Ikaw Lang
# 2                                           Anti-Hero
# 4                                               Ditto
# 48                                              Yakap
# 6                        Wet The Bed (feat. Ludacris)
# 1                                              Mahika
# 46                                                OMG
# 45                                             Kagome
# 44                                   I Wanna Be Yours
# 12                                             Umaasa
# 21                                        ANTIFRAGILE
# 49                                          Shut Down
# 31             Creepin' (with The Weeknd & 21 Savage)
# 32                                         Angel Baby
# 34                                      Glimpse of Us
# 41               Kumpas - Theme of “2 Good 2 Be True”
# ...

# %%
## songs with same key, do they have same crowd ratings?

# %%
crowdsource
# Out:
#     Unnamed: 0                                          Song Name  \
# 0            0                                          Kill Bill
# 1            1  Until I Found You (with Em Beihold) - Em Beiho...
# 2            2                                          THE SHADE
# 3            3                                      Glimpse of Us
# 4            4                                                OMG
# 5            5                                             Mahika
# 6            6                                      Midnight Rain
# 7            7                                           Isa lang
# 8            8                                   I Wanna Be Yours
# 9            9                                              Yakap
# 10          10                                          Anti-Hero
# 11          11                                             Umaasa
# 12          12            Left and Right (Feat. Jung Kook of BTS)
# ...

# %%
key_songs = merged[merged['key'] == 0]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 1]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 2]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 3]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 4]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 5]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 6]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 7]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 8]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 9]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 10]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)

# %%
key_songs = merged[merged['key'] == 11]
boxplot = key_songs.boxplot(column=['AR[bad-good]', 'AR[distasteful-tasty]', 'AR[dull-exciting]', 'AR[tasteless-tasteful]', 'AR[unimaginative-creative]', 'AR[untalented-talented]', 'AR[unpleasant-pleasant]', 'AR[forgettable-memorable]', 'AR[boring-interesting]', 'NR[listen to similar songs]', 'NR[share to my friends]', 'NR[add to my playlist]'], figsize=(20,10), rot=90)
