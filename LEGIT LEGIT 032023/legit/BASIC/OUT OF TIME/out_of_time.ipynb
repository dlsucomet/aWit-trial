# %% [markdown]
# # out of time

# %%
# !pip install semopy
# Out:
# Requirement already satisfied: semopy in d:\anaconda3\lib\site-packages (2.3.9)
# Requirement already satisfied: sympy in d:\anaconda3\lib\site-packages (from semopy) (1.8)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from semopy) (1.22.4)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from semopy) (1.2.4)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from semopy) (1.6.2)
# Requirement already satisfied: statsmodels in d:\anaconda3\lib\site-packages (from semopy) (0.12.2)
# Requirement already satisfied: sklearn in d:\anaconda3\lib\site-packages (from semopy) (0.0.post1)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda3\lib\site-packages (from pandas->semopy) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\anaconda3\lib\site-packages (from pandas->semopy) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python38\site-packages (from python-dateutil>=2.7.3->pandas->semopy) (1.16.0)
# Requirement already satisfied: patsy>=0.5 in d:\anaconda3\lib\site-packages (from statsmodels->semopy) (0.5.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda3\lib\site-packages (from sympy->semopy) (1.2.1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics as statistics
import semopy as sem

np.random.seed(1)

# %%
songs = pd.read_csv('ThesisHits.csv', index_col=0)
data = songs
print(data)
# Out:
#                                 title                   artist/s  \
# 0                 Uhaw (Tayong Lahat)                      Dilaw
# 1                             Elevate                Jeff Grecia
# 2                              Snooze                        SZA
# 3                   Cupid - Twin Ver.                FIFTY FIFTY
# 4   All Of The Girls You Loved Before               Taylor Swift
# 5                            Reminder                 The Weeknd
# 6                            Nonsense          Sabrina Carpenter
# 7                  Boy's a Liar Pt. 2  PinkPantheress, Ice Spice
# 8                             Flowers                Miley Cyrus
# 9                          Those Eyes                   New West
# 10                               Uhaw                      Dilaw
# 11                              LIMBO                      keshi
# 12                              Tally                  BLACKPINK
# 13                       Cruel Summer               Taylor Swift
# 14                          Enchanted               Taylor Swift
# 15                          panaginip                      iluna
# 16                              Style               Taylor Swift
# 17                        Ikaw Pa Rin                       mrld
# 18               Say You Won't Let Go               James Arthur
# 19                             lowkey                       NIKI
# 20                              Ghost              Justin Bieber
# 21                           cardigan               Taylor Swift
# 22                      Lavender Haze               Taylor Swift
# 23            Come Inside Of My Heart               IV Of Spades
# 24                            Tadhana             Up Dharma Down
# 25                               Sino             Unique Salonga
# 26                               Higa                Arthur Nery
# 27                            Players                  Coi Leray
# 28                         Pink Venom                  BLACKPINK
# 29                        Blank Space               Taylor Swift
# 30             Is There Someone Else?                 The Weeknd
# 31                              Lover               Taylor Swift
# 32                             Ligaya                       mrld
# 33                   Set Me Free Pt.2                      Jimin
# 34                              Cupid                FIFTY FIFTY
# 35                  Paninindigan Kita                    Ben&Ben
# 36                       Kathang Isip                    Ben&Ben
# 37                 Nahuhulog Na Sa'yo             Noah Alejandre
# 38                      Night Changes              One Direction
# 39                          Araw-Araw                    Ben&Ben
# 40               Bumalik Ka Na Sa'kin           Silent Sanctuary
# 41                               NVMD               Denise Julia
# 42                         Like Crazy                      Jimin
# 43                                 YK                   Cean Jr.
# 44                         Dandelions                    Ruth B.
# 45         Sa Susunod na Habang Buhay                    Ben&Ben
# 46                                BMW            Because, Leslie
# 47                             august               Taylor Swift
# 48                      I Love You So                The Walters
# 49                              Mundo               IV Of Spades
# 50                   Every Summertime                       NIKI
# 51                     Don't Blame Me               Taylor Swift
# 42         0.629    7    -5.445       0.0419    0.3570   0.3620  120.001
# 43         0.717    6    -7.872       0.0349    0.0721   0.5380  118.005
# 44         0.609    1    -2.958       0.0259    0.0864   0.4540  116.959
# 45         0.311    2    -8.889       0.0320    0.1140   0.2740  177.158
# 46         0.758    1    -9.799       0.0485    0.0990   0.2380  117.048
# 47         0.532    5    -9.208       0.0331    0.0925   0.4030   89.937
# 48         0.575   10    -4.891       0.0358    0.1150   0.4660   75.977
# 49         0.705    6    -8.900       0.0376    0.0735   0.4810  140.031
# 50         0.628    6    -4.227       0.0424    0.0978   0.7230   78.996
# 51         0.615    9    -6.719       0.0386    0.0607   0.1930  135.917
# 52         0.630    9    -7.140       0.0290    0.1220   0.5010  134.774
# 53         0.843    9    -8.114       0.3250    0.5770   0.4450   71.007
# 54         0.696    2   -10.289       0.0656    0.1250   0.3800  120.041
#
#     duration_ms  streams  stream_category            artist1     artist2  \
# 0        241186  3976673               10              Dilaw         NaN
# 1        218651  2929741               10        Jeff Grecia         NaN
# 2        201800  2754346               10                SZA         NaN
# 3        174253  2484998               10        FIFTY FIFTY         NaN
# 4        221407  2357174               10       Taylor Swift         NaN
# 5        218880  1724516               10         The Weeknd         NaN
# 6        163648  1556006               10  Sabrina Carpenter         NaN
# 7        131013  1512406                9     PinkPantheress   Ice Spice
# 8        200455  1476060                9        Miley Cyrus         NaN
# 9        220750  1413232                9           New West         NaN
# 10       267049  1400959                9              Dilaw         NaN
# 11       212785  1324787                9              keshi         NaN
# 12       184248  1295733                9          BLACKPINK         NaN
# 13       178427  1286776                9       Taylor Swift         NaN
# 14       352200  1262696                9       Taylor Swift         NaN
# 15       332406  1259591                9              iluna         NaN
# 16       231000  1163877                9       Taylor Swift         NaN
# 17       191009  1131169                9               mrld         NaN
# 18       211467  1074865                9       James Arthur         NaN
# 19       171356  1054822                9               NIKI         NaN
# 20       153190  1048030                9      Justin Bieber         NaN
# 21       239560   961745                9       Taylor Swift         NaN
# 22       202396   915701                8       Taylor Swift         NaN
# 23       246396   888601                8       IV Of Spades         NaN
# 24       222447   888375                8     Up Dharma Down         NaN
# 25       280427   872572                8     Unique Salonga         NaN
# 26       245760   872147                8        Arthur Nery         NaN
# 27       139560   866509                8          Coi Leray         NaN
# 28       186964   861606                8          BLACKPINK         NaN
# 29       231827   848774                7       Taylor Swift         NaN
# 30       199111   847024                7         The Weeknd         NaN
# 31       221307   844437                7       Taylor Swift         NaN
# 32       248800   840189                7               mrld         NaN
# 33       200930   836597                7              Jimin         NaN
# 34       174253   830154                7        FIFTY FIFTY         NaN
# 35       312234   829193                7            Ben&Ben         NaN
# 36       318814   822137                7            Ben&Ben         NaN
# 37       217037   799155                7     Noah Alejandre         NaN
# 38       226600   788791                7      One Direction         NaN
# 39       313952   785977                7            Ben&Ben         NaN
# 40       216387   784691                7   Silent Sanctuary         NaN
# 41       181224   784419                7       Denise Julia         NaN
# 42       212241   764007                7              Jimin         NaN
# 43       170263   751700                7           Cean Jr.         NaN
# 44       233720   750444                7            Ruth B.         NaN
# 45       288189   735211                6            Ben&Ben         NaN
# 46       168205   729377                6            Because      Leslie
# 47       261923   729048                6       Taylor Swift         NaN
# 48       160240   728760                6        The Walters         NaN
# 49       349713   727066                6       IV Of Spades         NaN
# 50       215687   704132                6               NIKI         NaN
# 51       236413   701046                6       Taylor Swift         NaN
# 52       246667   698171                6            Dionela         NaN
# 53       162029   697112                6     Calvin De Leon        Kiyo
# 54       194207   696120                6       Taylor Swift         NaN
#
#     artist3
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37      NaN
# 38      NaN
# 39      NaN
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 44      NaN
# 45      NaN
# 46      NaN
# 47      NaN
# 48      NaN
# 49      NaN
# 50      NaN
# 51      NaN
# 52      NaN
# 53      NaN
# 54      NaN

# %%
data = data.drop(columns=['streams', 'stream_category'])

# %%
extrinsic = data[['title', 'artist1']]
extrinsic
# Out:
#                                 title            artist1
# 0                 Uhaw (Tayong Lahat)              Dilaw
# 1                             Elevate        Jeff Grecia
# 2                              Snooze                SZA
# 3                   Cupid - Twin Ver.        FIFTY FIFTY
# 4   All Of The Girls You Loved Before       Taylor Swift
# 5                            Reminder         The Weeknd
# 6                            Nonsense  Sabrina Carpenter
# 7                  Boy's a Liar Pt. 2     PinkPantheress
# 8                             Flowers        Miley Cyrus
# 9                          Those Eyes           New West
# 10                               Uhaw              Dilaw
# 11                              LIMBO              keshi
# 12                              Tally          BLACKPINK
# 13                       Cruel Summer       Taylor Swift
# 14                          Enchanted       Taylor Swift
# 15                          panaginip              iluna
# 16                              Style       Taylor Swift
# 17                        Ikaw Pa Rin               mrld
# 18               Say You Won't Let Go       James Arthur
# 19                             lowkey               NIKI
# 20                              Ghost      Justin Bieber
# 21                           cardigan       Taylor Swift
# 22                      Lavender Haze       Taylor Swift
# 23            Come Inside Of My Heart       IV Of Spades
# 24                            Tadhana     Up Dharma Down
# 25                               Sino     Unique Salonga
# 26                               Higa        Arthur Nery
# 27                            Players          Coi Leray
# 28                         Pink Venom          BLACKPINK
# 29                        Blank Space       Taylor Swift
# 30             Is There Someone Else?         The Weeknd
# 31                              Lover       Taylor Swift
# 32                             Ligaya               mrld
# 33                   Set Me Free Pt.2              Jimin
# 34                              Cupid        FIFTY FIFTY
# 35                  Paninindigan Kita            Ben&Ben
# 36                       Kathang Isip            Ben&Ben
# 37                 Nahuhulog Na Sa'yo     Noah Alejandre
# 38                      Night Changes      One Direction
# 39                          Araw-Araw            Ben&Ben
# 40               Bumalik Ka Na Sa'kin   Silent Sanctuary
# 41                               NVMD       Denise Julia
# 42                         Like Crazy              Jimin
# 43                                 YK           Cean Jr.
# 44                         Dandelions            Ruth B.
# 45         Sa Susunod na Habang Buhay            Ben&Ben
# 46                                BMW            Because
# 47                             august       Taylor Swift
# 48                      I Love You So        The Walters
# 49                              Mundo       IV Of Spades
# 50                   Every Summertime               NIKI
# 51                     Don't Blame Me       Taylor Swift
# 52                             Musika            Dionela
# 53               Ano Na? (feat. Kiyo)     Calvin De Leon
# 54            You're On Your Own, Kid       Taylor Swift

# %%
# labels = pd.read_csv('music_labels.csv')
# labels

# %%
# categ = []
# for row in labels['Category']:
#     categ.append(row)
        
# extrinsic['music_label'] = categ
# extrinsic

# %%
collab = []
for row in songs['artist2']:
    if pd.isnull(row): collab.append('0')
    else: collab.append('1')
        
extrinsic['artist_collab'] = collab
extrinsic
# Out:
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/1655056029.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   extrinsic['artist_collab'] = collab
#                                 title            artist1 artist_collab
# 0                 Uhaw (Tayong Lahat)              Dilaw             0
# 1                             Elevate        Jeff Grecia             0
# 2                              Snooze                SZA             0
# 3                   Cupid - Twin Ver.        FIFTY FIFTY             0
# 4   All Of The Girls You Loved Before       Taylor Swift             0
# 5                            Reminder         The Weeknd             0
# 6                            Nonsense  Sabrina Carpenter             0
# 7                  Boy's a Liar Pt. 2     PinkPantheress             1
# 8                             Flowers        Miley Cyrus             0
# 9                          Those Eyes           New West             0
# 10                               Uhaw              Dilaw             0
# 11                              LIMBO              keshi             0
# 12                              Tally          BLACKPINK             0
# 13                       Cruel Summer       Taylor Swift             0
# 14                          Enchanted       Taylor Swift             0
# 15                          panaginip              iluna             0
# 16                              Style       Taylor Swift             0
# 17                        Ikaw Pa Rin               mrld             0
# 18               Say You Won't Let Go       James Arthur             0
# 19                             lowkey               NIKI             0
# 20                              Ghost      Justin Bieber             0
# 21                           cardigan       Taylor Swift             0
# 22                      Lavender Haze       Taylor Swift             0
# 23            Come Inside Of My Heart       IV Of Spades             0
# 24                            Tadhana     Up Dharma Down             0
# 25                               Sino     Unique Salonga             0
# 26                               Higa        Arthur Nery             0
# 27                            Players          Coi Leray             0
# 28                         Pink Venom          BLACKPINK             0
# 29                        Blank Space       Taylor Swift             0
# 30             Is There Someone Else?         The Weeknd             0
# 31                              Lover       Taylor Swift             0
# 32                             Ligaya               mrld             0
# 33                   Set Me Free Pt.2              Jimin             0
# 34                              Cupid        FIFTY FIFTY             0
# 35                  Paninindigan Kita            Ben&Ben             0
# 36                       Kathang Isip            Ben&Ben             0
# 37                 Nahuhulog Na Sa'yo     Noah Alejandre             0
# 38                      Night Changes      One Direction             0
# 39                          Araw-Araw            Ben&Ben             0
# 40               Bumalik Ka Na Sa'kin   Silent Sanctuary             0
# 41                               NVMD       Denise Julia             0
# 42                         Like Crazy              Jimin             0
# 43                                 YK           Cean Jr.             0
# 44                         Dandelions            Ruth B.             0
# 45         Sa Susunod na Habang Buhay            Ben&Ben             0
# 46                                BMW            Because             1
# 47                             august       Taylor Swift             0
# 48                      I Love You So        The Walters             0
# 49                              Mundo       IV Of Spades             0
# 50                   Every Summertime               NIKI             0
# 51                     Don't Blame Me       Taylor Swift             0
# 52                             Musika            Dionela             0
# 53               Ano Na? (feat. Kiyo)     Calvin De Leon             1
# 54            You're On Your Own, Kid       Taylor Swift             0

# %%
history = pd.read_csv('chart_history.csv')
history
# Out:
#                artist  weeks
# 0        Taylor Swift     85
# 1          The Weeknd     85
# 2               Dilaw     13
# 3         Jeff Grecia     13
# 4                 SZA     85
# 5         FIFTY FIFTY     13
# 6   Sabrina Carpenter     28
# 7      PinkPantheress     17
# 8         Miley Cyrus     85
# 9            New West     27
# 10              keshi     85
# 11          BLACKPINK     85
# 12              iluna     20
# 13               mrld     77
# 14       James Arthur     85
# 15               NIKI     85
# 16      Justin Bieber     85
# 17       IV Of Spades     85
# 18     Up Dharma Down     48
# 19     Unique Salonga     18
# 20        Arthur Nery     85
# 21          Coi Leray      0
# 22              Jimin     11
# 23            Ben&Ben     85
# 24   Silent Sanctuary      0
# 25       Denise Julia      0
# 26           Cean Jr.      0
# 27            Ruth B.     85
# 28            Because     85
# 29        The Walters      0
# 30            Dionela     10
# 31     Calvin De Leon      0
# 32      One Direction     85
# 33     Noah Alejandre      0

# %%
extrinsic = pd.merge(extrinsic, history, how='left', left_on=['artist1'], right_on=['artist'])
extrinsic.drop(columns=['artist'], inplace=True)
extrinsic
# Out:
#                                 title            artist1 artist_collab  weeks
# 0                 Uhaw (Tayong Lahat)              Dilaw             0     13
# 1                             Elevate        Jeff Grecia             0     13
# 2                              Snooze                SZA             0     85
# 3                   Cupid - Twin Ver.        FIFTY FIFTY             0     13
# 4   All Of The Girls You Loved Before       Taylor Swift             0     85
# 5                            Reminder         The Weeknd             0     85
# 6                            Nonsense  Sabrina Carpenter             0     28
# 7                  Boy's a Liar Pt. 2     PinkPantheress             1     17
# 8                             Flowers        Miley Cyrus             0     85
# 9                          Those Eyes           New West             0     27
# 10                               Uhaw              Dilaw             0     13
# 11                              LIMBO              keshi             0     85
# 12                              Tally          BLACKPINK             0     85
# 13                       Cruel Summer       Taylor Swift             0     85
# 14                          Enchanted       Taylor Swift             0     85
# 15                          panaginip              iluna             0     20
# 16                              Style       Taylor Swift             0     85
# 17                        Ikaw Pa Rin               mrld             0     77
# 18               Say You Won't Let Go       James Arthur             0     85
# 19                             lowkey               NIKI             0     85
# 20                              Ghost      Justin Bieber             0     85
# 21                           cardigan       Taylor Swift             0     85
# 22                      Lavender Haze       Taylor Swift             0     85
# 23            Come Inside Of My Heart       IV Of Spades             0     85
# 24                            Tadhana     Up Dharma Down             0     48
# 25                               Sino     Unique Salonga             0     18
# 26                               Higa        Arthur Nery             0     85
# 27                            Players          Coi Leray             0      0
# 28                         Pink Venom          BLACKPINK             0     85
# 29                        Blank Space       Taylor Swift             0     85
# 30             Is There Someone Else?         The Weeknd             0     85
# 31                              Lover       Taylor Swift             0     85
# 32                             Ligaya               mrld             0     77
# 33                   Set Me Free Pt.2              Jimin             0     11
# 34                              Cupid        FIFTY FIFTY             0     13
# 35                  Paninindigan Kita            Ben&Ben             0     85
# 36                       Kathang Isip            Ben&Ben             0     85
# 37                 Nahuhulog Na Sa'yo     Noah Alejandre             0      0
# 38                      Night Changes      One Direction             0     85
# 39                          Araw-Araw            Ben&Ben             0     85
# 40               Bumalik Ka Na Sa'kin   Silent Sanctuary             0      0
# 41                               NVMD       Denise Julia             0      0
# 42                         Like Crazy              Jimin             0     11
# 43                                 YK           Cean Jr.             0      0
# 44                         Dandelions            Ruth B.             0     85
# 45         Sa Susunod na Habang Buhay            Ben&Ben             0     85
# 46                                BMW            Because             1     85
# 47                             august       Taylor Swift             0     85
# 48                      I Love You So        The Walters             0      0
# 49                              Mundo       IV Of Spades             0     85
# 50                   Every Summertime               NIKI             0     85
# 51                     Don't Blame Me       Taylor Swift             0     85
# 52                             Musika            Dionela             0     10
# 53               Ano Na? (feat. Kiyo)     Calvin De Leon             1      0
# 54            You're On Your Own, Kid       Taylor Swift             0     85

# %%
extrinsic.rename(columns={"weeks": "chart_history"}, inplace=True)

# %%
import glob
import os
import functools

path = r'C:\Users\angel\OneDrive\Github\aWit-trial\LEGIT LEGIT 032023\legit\BASIC\OUT OF TIME\google trends'
all_files = glob.glob(os.path.join(path, "*.csv"))

df_from_each_file = (pd.read_csv(f, skiprows=2) for f in all_files)
# trends = pd.concat(df_from_each_file, join='outer', on=['day'], axis=1)
trends = functools.reduce(lambda left,right: pd.merge(left,right,on='Day'), df_from_each_file)
trends
# Out:
#            Day  Arthur Nery: (Philippines)  Because: (Philippines)  \
# 0   2023-03-24                          81                      77
# 1   2023-03-25                          63                      77
# 2   2023-03-26                          39                      77
# 3   2023-03-27                          24                      97
# 4   2023-03-28                          48                      91
# ..         ...                         ...                     ...
# 65  2023-05-28                          63                      82
# 66  2023-05-29                          19                      72
# 67  2023-05-30                          63                      82
# 68  2023-05-31                          80                      71
# 69  2023-06-01                          63                      76
#
#     Ben&Ben: (Philippines)  BLACKPINK: (Philippines)  \
# 0                       21                        41
# 1                       45                        88
# 2                       37                       100
# 3                       28                        70
# 4                       54                        43
# ..                     ...                       ...
# 65                      52                        17
# 66                      57                         9
# 67                      37                        11
# 68                      35                        14
# 69                      36                        13
#
#     Calvin De Leon: (Philippines)  Cean Jr.: (Philippines)  \
# 0                               0                       34
# 1                               0                        0
# 2                               0                        0
# 3                              38                        0
# 4                               0                       17
# ..                            ...                      ...
# 65                              0                       22
# 66                              0                        0
# 67                              0                        0
# 68                             21                        0
# 69                              0                        0
#
#     Coi Leray: (Philippines)  Denise Julia: (Philippines)  \
# 0                          0                            0
# 1                          0                           76
# 2                          0                            0
# 3                          0                            0
# 4                         57                            0
# ..                       ...                          ...
# 65                         0                            0
# 66                        36                            0
# 67                         0                            0
# 68                        34                           78
# 69                         0                            0
#
#     Dilaw: (Philippines)  ...  PinkPantheress: (Philippines)  \
# 0                     36  ...                             82
# 1                     52  ...                             67
# 2                     52  ...                             67
# 3                     33  ...                              0
# 4                     23  ...                             33
# ..                   ...  ...                            ...
# 65                    51  ...                              0
# 66                    34  ...                              0
# 67                    33  ...                              0
# 68                    30  ...                              0
# 69                    36  ...                              0
#
#     Ruth B: (Philippines)  Sabrina Carpenter: (Philippines)  \
# 0                       0                                 0
# 1                      73                                22
# 2                      51                                28
# 3                      59                                 7
# 4                       0                                 6
# ..                    ...                               ...
# 65                      0                                15
# 66                      0                                14
# 67                      0                                 5
# 68                      0                                 8
# 69                     39                                12
#
#     Silent Sanctuary: (Philippines)  SZA: (Philippines)  \
# 0                                41                  97
# 1                                34                  89
# 2                                42                 100
# 3                                39                  50
# 4                                32                  67
# ..                              ...                 ...
# 65                               62                  70
# 66                               50                  40
# 67                               27                  39
# 68                               29                  45
# 69                               64                  39
#
#     Taylor Swift: (Philippines)  The Walters: (Philippines)  \
# 0                            33                           0
# 1                            35                          50
# 2                            34                           0
# 3                            29                           0
# 4                            24                           0
# ..                          ...                         ...
# 65                           45                           0
# 66                           42                           0
# 67                           38                           0
# 68                           33                          43
# 69                           33                           0
#
#     The Weeknd: (Philippines)  Unique: (Philippines)  UDD: (Philippines)
# 0                          81                      0                  58
# 1                          65                     37                  28
# 2                         100                     36                   0
# 3                          41                     22                  38
# 4                          54                     40                  27
# ..                        ...                    ...                 ...
# 65                         35                     30                  51
# 66                         39                     20                  40
# 67                         25                     35                  44
# 68                         28                     21                   0
# 69                         32                     33                  31
#
# [70 rows x 35 columns]

# %%
# trends.columns = trends.columns.str.replace(': (Philippines)', '')
trends.columns = [col.replace(': (Philippines)', '') for col in trends.columns]
trends.columns = trends.columns.str.lower()
trends
# Out:
#            day  arthur nery  because  ben&ben  blackpink  calvin de leon  \
# 0   2023-03-24           81       77       21         41               0
# 1   2023-03-25           63       77       45         88               0
# 2   2023-03-26           39       77       37        100               0
# 3   2023-03-27           24       97       28         70              38
# 4   2023-03-28           48       91       54         43               0
# ..         ...          ...      ...      ...        ...             ...
# 65  2023-05-28           63       82       52         17               0
# 66  2023-05-29           19       72       57          9               0
# 67  2023-05-30           63       82       37         11               0
# 68  2023-05-31           80       71       35         14              21
# 69  2023-06-01           63       76       36         13               0
#
#     cean jr.  coi leray  denise julia  dilaw  ...  pinkpantheress  ruth b  \
# 0         34          0             0     36  ...              82       0
# 1          0          0            76     52  ...              67      73
# 2          0          0             0     52  ...              67      51
# 3          0          0             0     33  ...               0      59
# 4         17         57             0     23  ...              33       0
# ..       ...        ...           ...    ...  ...             ...     ...
# 65        22          0             0     51  ...               0       0
# 66         0         36             0     34  ...               0       0
# 67         0          0             0     33  ...               0       0
# 68         0         34            78     30  ...               0       0
# 69         0          0             0     36  ...               0      39
#
#     sabrina carpenter  silent sanctuary  sza  taylor swift  the walters  \
# 0                   0                41   97            33            0
# 1                  22                34   89            35           50
# 2                  28                42  100            34            0
# 3                   7                39   50            29            0
# 4                   6                32   67            24            0
# ..                ...               ...  ...           ...          ...
# 65                 15                62   70            45            0
# 66                 14                50   40            42            0
# 67                  5                27   39            38            0
# 68                  8                29   45            33           43
# 69                 12                64   39            33            0
#
#     the weeknd  unique  udd
# 0           81       0   58
# 1           65      37   28
# 2          100      36    0
# 3           41      22   38
# 4           54      40   27
# ..         ...     ...  ...
# 65          35      30   51
# 66          39      20   40
# 67          25      35   44
# 68          28      21    0
# 69          32      33   31
#
# [70 rows x 35 columns]

# %%
trends.rename(columns={"unique": "unique salonga"}, inplace=True)
trends.rename(columns={"udd": "up dharma down"}, inplace=True)
trends.rename(columns={"ruth b": "ruth b."}, inplace=True)
trends
# Out:
#            day  arthur nery  because  ben&ben  blackpink  calvin de leon  \
# 0   2023-03-24           81       77       21         41               0
# 1   2023-03-25           63       77       45         88               0
# 2   2023-03-26           39       77       37        100               0
# 3   2023-03-27           24       97       28         70              38
# 4   2023-03-28           48       91       54         43               0
# ..         ...          ...      ...      ...        ...             ...
# 65  2023-05-28           63       82       52         17               0
# 66  2023-05-29           19       72       57          9               0
# 67  2023-05-30           63       82       37         11               0
# 68  2023-05-31           80       71       35         14              21
# 69  2023-06-01           63       76       36         13               0
#
#     cean jr.  coi leray  denise julia  dilaw  ...  pinkpantheress  ruth b.  \
# 0         34          0             0     36  ...              82        0
# 1          0          0            76     52  ...              67       73
# 2          0          0             0     52  ...              67       51
# 3          0          0             0     33  ...               0       59
# 4         17         57             0     23  ...              33        0
# ..       ...        ...           ...    ...  ...             ...      ...
# 65        22          0             0     51  ...               0        0
# 66         0         36             0     34  ...               0        0
# 67         0          0             0     33  ...               0        0
# 68         0         34            78     30  ...               0        0
# 69         0          0             0     36  ...               0       39
#
#     sabrina carpenter  silent sanctuary  sza  taylor swift  the walters  \
# 0                   0                41   97            33            0
# 1                  22                34   89            35           50
# 2                  28                42  100            34            0
# 3                   7                39   50            29            0
# 4                   6                32   67            24            0
# ..                ...               ...  ...           ...          ...
# 65                 15                62   70            45            0
# 66                 14                50   40            42            0
# 67                  5                27   39            38            0
# 68                  8                29   45            33           43
# 69                 12                64   39            33            0
#
#     the weeknd  unique salonga  up dharma down
# 0           81               0              58
# 1           65              37              28
# 2          100              36               0
# 3           41              22              38
# 4           54              40              27
# ..         ...             ...             ...
# 65          35              30              51
# 66          39              20              40
# 67          25              35              44
# 68          28              21               0
# 69          32              33              31
#
# [70 rows x 35 columns]

# %%
# songs['artist1'] = songs['artist1'].str.lower()
# songs

# %%
trends = trends.transpose().reset_index().rename(columns={'index':'artist'})
trends
# Out:
#                artist           0           1           2           3  \
# 0                 day  2023-03-24  2023-03-25  2023-03-26  2023-03-27
# 1         arthur nery          81          63          39          24
# 2             because          77          77          77          97
# 3             ben&ben          21          45          37          28
# 4           blackpink          41          88         100          70
# 5      calvin de leon           0           0           0          38
# 6            cean jr.          34           0           0           0
# 7           coi leray           0           0           0           0
# 8        denise julia           0          76           0           0
# 9               dilaw          36          52          52          33
# 10            dionela          88          32          83          28
# 11        fifty fifty          68          90          74          67
# 12              iluna          18          77          27          52
# 13       iv of spades           0          37          54           0
# 14       james arthur           0          42          52          98
# 15        jeff grecia           0           0          71          32
# 16              jimin         100          91          57          51
# 17      justin bieber          94          77          92          67
# 18              keshi          38          93          45          44
# 19        miley cyrus          43          18          55          29
# 20               mrld          44         100          19          44
# 21           new west          42          37          41          56
# 22               niki           5           7          13           3
# 23     noah alejandre           0           0           0           0
# 24      one direction          78         100          74          53
# 25     pinkpantheress          82          67          67           0
# 26            ruth b.           0          73          51          59
# 27  sabrina carpenter           0          22          28           7
# 28   silent sanctuary          41          34          42          39
# 29                sza          97          89         100          50
# 30       taylor swift          33          35          34          29
# 31        the walters           0          50           0           0
# 28         53         39         48         62         50         27
# 29         59         46         77         70         40         39
# 30         28         34         49         45         42         38
# 31          0          0          0          0          0          0
# 32         50         33         36         35         39         25
# 33         43         52         50         30         20         35
# 34         23         61         45         51         40         44
#
# 0  2023-05-31 2023-06-01
# 1          80         63
# 2          71         76
# 3          35         36
# 4          14         13
# 5          21          0
# 6           0          0
# 7          34          0
# 8          78          0
# 9          30         36
# 10          0          0
# 11         34         52
# 12          0         55
# 13         25         26
# 14          0         34
# 15          0         16
# 16         12          9
# 17         40         35
# 18         24         26
# 19         81         99
# 20         19         19
# 21          0         51
# 22         11         17
# 23          0         31
# 24         41         60
# 25          0          0
# 26          0         39
# 27          8         12
# 28         29         64
# 29         45         39
# 30         33         33
# 31         43          0
# 32         28         32
# 33         21         33
# 34          0         31
#
# [34 rows x 71 columns]

# %%
trends.rename(columns={"day": "artist"}, inplace=True)
trends
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# 0              artist 2023-03-24 2023-03-25 2023-03-26 2023-03-27 2023-03-28  \
# 1         arthur nery         81         63         39         24         48
# 2             because         77         77         77         97         91
# 3             ben&ben         21         45         37         28         54
# 4           blackpink         41         88        100         70         43
# 5      calvin de leon          0          0          0         38          0
# 6            cean jr.         34          0          0          0         17
# 7           coi leray          0          0          0          0         57
# 8        denise julia          0         76          0          0          0
# 9               dilaw         36         52         52         33         23
# 10            dionela         88         32         83         28         51
# 11        fifty fifty         68         90         74         67         72
# 12              iluna         18         77         27         52         13
# 13       iv of spades          0         37         54          0         56
# 14       james arthur          0         42         52         98         27
# 15        jeff grecia          0          0         71         32         45
# 16              jimin        100         91         57         51         37
# 17      justin bieber         94         77         92         67         68
# 18              keshi         38         93         45         44         36
# 19        miley cyrus         43         18         55         29         34
# 20               mrld         44        100         19         44         16
# 21           new west         42         37         41         56         15
# 22               niki          5          7         13          3          4
# 23     noah alejandre          0          0          0          0         22
# 24      one direction         78        100         74         53         61
# 25     pinkpantheress         82         67         67          0         33
# 26            ruth b.          0         73         51         59          0
# 27  sabrina carpenter          0         22         28          7          6
# 28   silent sanctuary         41         34         42         39         32
# 29                sza         97         89        100         50         67
# 30       taylor swift         33         35         34         29         24
# 31        the walters          0         50          0          0          0
# 32         the weeknd         81         65        100         41         54
# 33     unique salonga          0         37         36         22         40
# 34     up dharma down         58         28          0         38         27
#
# 0  2023-03-29 2023-03-30 2023-03-31 2023-04-01  ... 2023-05-23 2023-05-24  \
# 1          36         35         34         59  ...         47         43
# 2          97         93         81         68  ...         96         89
# 3          69         42         44         67  ...         36         45
# 4          33         28         32         32  ...         12         12
# 5           0          0          0          0  ...          0          0
# 6           0          0          0          0  ...          0          0
# 7          97         33          0         62  ...         75          0
# 8           0         27          0         33  ...          0          0
# 9          41         36         29         41  ...         36         47
# 10          0         37         21         31  ...         27         36
# 11         59         63         59         88  ...         49         52
# 12         26          0         29         46  ...         19         19
# 13         41         77         59         30  ...         47         48
# 14         48         54         45         50  ...         15         19
# 15        100         20         19         37  ...         38          0
# 16         43         41         32         67  ...         33         12
# 17         69         63        100         67  ...         33         59
# 18         41         40         37         82  ...         21         33
# 19         32         39         36         26  ...         59         72
# 20         33         40         24         39  ...         26         32
# 21         16         67         23          0  ...          0         22
# 22          4          6          0         13  ...         26         11
# 23        100         28         47         74  ...          0          0
# 24         27         60         81         87  ...         51         27
# 25          0          0          0         30  ...          0          0
# 26          0          0          0         68  ...          0          0
# 27         14          0         19         42  ...          0          8
# 28         22         19         31        100  ...         40         54
# 29         78         75         59         76  ...         34         54
# 30         23         22         23         30  ...         26         25
# 31          0          0          0          0  ...         25          0
# 32         48         42         33         73  ...         42         56
# 33         38         25         28         36  ...         43         43
# 34         29         15         23         15  ...         32          0
#
# 0  2023-05-25 2023-05-26 2023-05-27 2023-05-28 2023-05-29 2023-05-30  \
# 1         100         51         90         63         19         63
# 2          84         76         69         82         72         82
# 3          50         62         54         52         57         37
# 4          11         13         17         17          9         11
# 5           0         23          0          0          0          0
# 6           0          0         35         22          0          0
# 7          66         83          0          0         36          0
# 8          46          0         44          0          0          0
# 9          34         36         33         51         34         33
# 10         38          0        100          0          0          0
# 11         56         68         58         41         47         52
# 12          0          0         33         20          0         16
# 13          0         72         47         51         50         72
# 14         27         38         86         16          0          0
# 15          0          0          0          0          0          0
# 16         14         15         37         18         19         30
# 17         42         38         53         51         36         33
# 18         15         20         29          0         39         40
# 19         68         52         84         62         62         59
# 20         32          0         39         42         27         30
# 21         44         48         46         40         25         35
# 22         12         23         17          9         13         10
# 23          0          0          0          0          0          0
# 24         66         57         40         48         70         49
# 25          0        100          0          0          0          0
# 26          0          0          0          0          0          0
# 27          0          0         19         15         14          5
# 28         53         39         48         62         50         27
# 29         59         46         77         70         40         39
# 30         28         34         49         45         42         38
# 31          0          0          0          0          0          0
# 32         50         33         36         35         39         25
# 33         43         52         50         30         20         35
# 34         23         61         45         51         40         44
#
# 0  2023-05-31 2023-06-01
# 1          80         63
# 2          71         76
# 3          35         36
# 4          14         13
# 5          21          0
# 6           0          0
# 7          34          0
# 8          78          0
# 9          30         36
# 10          0          0
# 11         34         52
# 12          0         55
# 13         25         26
# 14          0         34
# 15          0         16
# 16         12          9
# 17         40         35
# 18         24         26
# 19         81         99
# 20         19         19
# 21          0         51
# 22         11         17
# 23          0         31
# 24         41         60
# 25          0          0
# 26          0         39
# 27          8         12
# 28         29         64
# 29         45         39
# 30         33         33
# 31         43          0
# 32         28         32
# 33         21         33
# 34          0         31
#
# [34 rows x 71 columns]

# %%
trends['artist']
# Out:
# 1           arthur nery
# 2               because
# 3               ben&ben
# 4             blackpink
# 5        calvin de leon
# 6              cean jr.
# 7             coi leray
# 8          denise julia
# 9                 dilaw
# 10              dionela
# 11          fifty fifty
# 12                iluna
# 13         iv of spades
# 14         james arthur
# 15          jeff grecia
# 16                jimin
# 17        justin bieber
# 18                keshi
# 19          miley cyrus
# 20                 mrld
# 21             new west
# 22                 niki
# 23       noah alejandre
# 24        one direction
# 25       pinkpantheress
# 26              ruth b.
# 27    sabrina carpenter
# 28     silent sanctuary
# 29                  sza
# 30         taylor swift
# 31          the walters
# 32           the weeknd
# 33       unique salonga
# 34       up dharma down
# Name: artist, dtype: object

# %%
extrinsic['artist1'] = extrinsic['artist1'].str.lower()
extrinsic
# Out:
#                                 title            artist1 artist_collab  \
# 0                 Uhaw (Tayong Lahat)              dilaw             0
# 1                             Elevate        jeff grecia             0
# 2                              Snooze                sza             0
# 3                   Cupid - Twin Ver.        fifty fifty             0
# 4   All Of The Girls You Loved Before       taylor swift             0
# 5                            Reminder         the weeknd             0
# 6                            Nonsense  sabrina carpenter             0
# 7                  Boy's a Liar Pt. 2     pinkpantheress             1
# 8                             Flowers        miley cyrus             0
# 9                          Those Eyes           new west             0
# 10                               Uhaw              dilaw             0
# 11                              LIMBO              keshi             0
# 12                              Tally          blackpink             0
# 13                       Cruel Summer       taylor swift             0
# 14                          Enchanted       taylor swift             0
# 15                          panaginip              iluna             0
# 16                              Style       taylor swift             0
# 17                        Ikaw Pa Rin               mrld             0
# 18               Say You Won't Let Go       james arthur             0
# 19                             lowkey               niki             0
# 20                              Ghost      justin bieber             0
# 21                           cardigan       taylor swift             0
# 22                      Lavender Haze       taylor swift             0
# 23            Come Inside Of My Heart       iv of spades             0
# 24                            Tadhana     up dharma down             0
# 25                               Sino     unique salonga             0
# 26                               Higa        arthur nery             0
# 27                            Players          coi leray             0
# 28                         Pink Venom          blackpink             0
# 29                        Blank Space       taylor swift             0
# 30             Is There Someone Else?         the weeknd             0
# 31                              Lover       taylor swift             0
# 32                             Ligaya               mrld             0
# 33                   Set Me Free Pt.2              jimin             0
# 34                              Cupid        fifty fifty             0
# 35                  Paninindigan Kita            ben&ben             0
# 36                       Kathang Isip            ben&ben             0
# 37                 Nahuhulog Na Sa'yo     noah alejandre             0
# 38                      Night Changes      one direction             0
# 39                          Araw-Araw            ben&ben             0
# 40               Bumalik Ka Na Sa'kin   silent sanctuary             0
# 41                               NVMD       denise julia             0
# 42                         Like Crazy              jimin             0
# 43                                 YK           cean jr.             0
# 44                         Dandelions            ruth b.             0
# 45         Sa Susunod na Habang Buhay            ben&ben             0
# 46                                BMW            because             1
# 47                             august       taylor swift             0
# 48                      I Love You So        the walters             0
# 49                              Mundo       iv of spades             0
# 50                   Every Summertime               niki             0
# 51                     Don't Blame Me       taylor swift             0
# 52                             Musika            dionela             0
# 53               Ano Na? (feat. Kiyo)     calvin de leon             1
# 54            You're On Your Own, Kid       taylor swift             0
#
#     chart_history
# 0              13
# 1              13
# 2              85
# 3              13
# 4              85
# 5              85
# 6              28
# 7              17
# 8              85
# 9              27
# 10             13
# 11             85
# 12             85
# 13             85
# 14             85
# 15             20
# 16             85
# 17             77
# 18             85
# 19             85
# 20             85
# 21             85
# 22             85
# 23             85
# 24             48
# 25             18
# 26             85
# 27              0
# 28             85
# 29             85
# 30             85
# 31             85
# 32             77
# 33             11
# 34             13
# 35             85
# 36             85
# 37              0
# 38             85
# 39             85
# 40              0
# 41              0
# 42             11
# 43              0
# 44             85
# 45             85
# 46             85
# 47             85
# 48              0
# 49             85
# 50             85
# 51             85
# 52             10
# 16         45         42         38         33         33
# 17         42         27         30         19         19
# 18         16          0          0          0         34
# 19          9         13         10         11         17
# 20         51         36         33         40         35
# 21         45         42         38         33         33
# 22         45         42         38         33         33
# 23         51         50         72         25         26
# 24         51         40         44          0         31
# 25         30         20         35         21         33
# 26         63         19         63         80         63
# 27          0         36          0         34          0
# 28         17          9         11         14         13
# 29         45         42         38         33         33
# 30         35         39         25         28         32
# 31         45         42         38         33         33
# 32         42         27         30         19         19
# 33         18         19         30         12          9
# 34         41         47         52         34         52
# 35         52         57         37         35         36
# 36         52         57         37         35         36
# 37          0          0          0          0         31
# 38         48         70         49         41         60
# 39         52         57         37         35         36
# 40         62         50         27         29         64
# 41          0          0          0         78          0
# 42         18         19         30         12          9
# 43         22          0          0          0          0
# 44          0          0          0          0         39
# 45         52         57         37         35         36
# 46         82         72         82         71         76
# 47         45         42         38         33         33
# 48          0          0          0         43          0
# 49         51         50         72         25         26
# 50          9         13         10         11         17
# 51         45         42         38         33         33
# 52          0          0          0          0          0
# 53          0          0          0         21          0
# 54         45         42         38         33         33
#
# [55 rows x 74 columns]

# %%
extrinsic['mean_trends'] = extrinsic.iloc[:, 4:67].mean(axis=1)

# %%
# extrinsic.iloc[:, 4:67]

# %%
# music_label = extrinsic["music_label"]
artist_collab = extrinsic["artist_collab"]
chart_history = extrinsic["chart_history"] - 1
mean_trends = extrinsic["mean_trends"]

# data = data.join(music_label)
data = data.join(artist_collab)
data = data.join(chart_history)
data = data.join(mean_trends)
data
# Out:
#                                 title                   artist/s  \
# 0                 Uhaw (Tayong Lahat)                      Dilaw
# 1                             Elevate                Jeff Grecia
# 2                              Snooze                        SZA
# 3                   Cupid - Twin Ver.                FIFTY FIFTY
# 4   All Of The Girls You Loved Before               Taylor Swift
# 5                            Reminder                 The Weeknd
# 6                            Nonsense          Sabrina Carpenter
# 7                  Boy's a Liar Pt. 2  PinkPantheress, Ice Spice
# 8                             Flowers                Miley Cyrus
# 9                          Those Eyes                   New West
# 10                               Uhaw                      Dilaw
# 11                              LIMBO                      keshi
# 12                              Tally                  BLACKPINK
# 13                       Cruel Summer               Taylor Swift
# 14                          Enchanted               Taylor Swift
# 15                          panaginip                      iluna
# 16                              Style               Taylor Swift
# 17                        Ikaw Pa Rin                       mrld
# 18               Say You Won't Let Go               James Arthur
# 19                             lowkey                       NIKI
# 20                              Ghost              Justin Bieber
# 21                           cardigan               Taylor Swift
# 22                      Lavender Haze               Taylor Swift
# 23            Come Inside Of My Heart               IV Of Spades
# 24                            Tadhana             Up Dharma Down
# 25                               Sino             Unique Salonga
# 26                               Higa                Arthur Nery
# 27                            Players                  Coi Leray
# 28                         Pink Venom                  BLACKPINK
# 29                        Blank Space               Taylor Swift
# 30             Is There Someone Else?                 The Weeknd
# 31                              Lover               Taylor Swift
# 32                             Ligaya                       mrld
# 33                   Set Me Free Pt.2                      Jimin
# 34                              Cupid                FIFTY FIFTY
# 35                  Paninindigan Kita                    Ben&Ben
# 36                       Kathang Isip                    Ben&Ben
# 19       171356             0             84    13.047619
# 20       153190             0             84    56.126984
# 21       239560             0             84    28.714286
# 22       202396             0             84    28.714286
# 23       246396             0             84    44.984127
# 24       222447             0             47    31.507937
# 25       280427             0             17    32.158730
# 26       245760             0             84    48.650794
# 27       139560             0             -1    14.698413
# 28       186964             0             84    23.809524
# 29       231827             0             84    28.714286
# 30       199111             0             84    48.777778
# 31       221307             0             84    28.714286
# 32       248800             0             76    33.015873
# 33       200930             0             10    37.047619
# 34       174253             0             12    67.920635
# 35       312234             0             84    47.126984
# 36       318814             0             84    47.126984
# 37       217037             0             -1    15.714286
# 38       226600             0             84    54.841270
# 39       313952             0             84    47.126984
# 40       216387             0             -1    42.047619
# 41       181224             0             -1    16.634921
# 42       212241             0             10    37.047619
# 43       170263             0             -1     8.111111
# 44       233720             0             84    18.952381
# 45       288189             0             84    47.126984
# 46       168205             1             84    81.888889
# 47       261923             0             84    28.714286
# 48       160240             0             -1    10.634921
# 49       349713             0             84    44.984127
# 50       215687             0             84    13.047619
# 51       236413             0             84    28.714286
# 52       246667             0              9    28.428571
# 53       162029             1             -1     9.126984
# 54       194207             0             84    28.714286

# %%
week1 = pd.read_csv('week1 - streamcategory.csv')
week2 = pd.read_csv('week2 - streamcategory.csv')
week3 = pd.read_csv('week3 - streamcategory.csv')
week4 = pd.read_csv('week4 - streamcategory.csv')
week5 = pd.read_csv('week5 - streamcategory.csv')
week6 = pd.read_csv('week6 - streamcategory.csv')
week7 = pd.read_csv('week7 - streamcategory.csv')
week8 = pd.read_csv('week8 - streamcategory.csv')
week9 = pd.read_csv('week9 - streamcategory.csv')

week1.rename(columns={"stream_category": "stream1"}, inplace=True)
week2.rename(columns={"stream_category": "stream2"}, inplace=True)
week3.rename(columns={"stream_category": "stream3"}, inplace=True)
week4.rename(columns={"stream_category": "stream4"}, inplace=True)
week5.rename(columns={"stream_category": "stream5"}, inplace=True)
week6.rename(columns={"stream_category": "stream6"}, inplace=True)
week7.rename(columns={"stream_category": "stream7"}, inplace=True)
week8.rename(columns={"stream_category": "stream8"}, inplace=True)
week9.rename(columns={"stream_category": "stream9"}, inplace=True)

week1.rename(columns={"track_name": "title"}, inplace=True)
week2.rename(columns={"track_name": "title"}, inplace=True)
week3.rename(columns={"track_name": "title"}, inplace=True)
week4.rename(columns={"track_name": "title"}, inplace=True)
week5.rename(columns={"track_name": "title"}, inplace=True)
week6.rename(columns={"track_name": "title"}, inplace=True)
week7.rename(columns={"track_name": "title"}, inplace=True)
week8.rename(columns={"track_name": "title"}, inplace=True)
week9.rename(columns={"track_name": "title"}, inplace=True)

week1.rename(columns={"artist_names": "artist/s"}, inplace=True)
week2.rename(columns={"artist_names": "artist/s"}, inplace=True)
week3.rename(columns={"artist_names": "artist/s"}, inplace=True)
week4.rename(columns={"artist_names": "artist/s"}, inplace=True)
week5.rename(columns={"artist_names": "artist/s"}, inplace=True)
week6.rename(columns={"artist_names": "artist/s"}, inplace=True)
week7.rename(columns={"artist_names": "artist/s"}, inplace=True)
week8.rename(columns={"artist_names": "artist/s"}, inplace=True)
week9.rename(columns={"artist_names": "artist/s"}, inplace=True)

data = pd.merge(data, week1[['title', 'artist/s', 'stream1']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week2[['title', 'artist/s', 'stream2']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week3[['title', 'artist/s', 'stream3']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week4[['title', 'artist/s', 'stream4']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week5[['title', 'artist/s', 'stream5']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week6[['title', 'artist/s', 'stream6']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week7[['title', 'artist/s', 'stream7']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week8[['title', 'artist/s', 'stream8']], how='left', on=['title', 'artist/s'])
data = pd.merge(data, week9[['title', 'artist/s', 'stream9']], how='left', on=['title', 'artist/s'])

print(data)
# Out:
#                                 title                   artist/s  \
# 0                 Uhaw (Tayong Lahat)                      Dilaw
# 1                             Elevate                Jeff Grecia
# 2                              Snooze                        SZA
# 3                   Cupid - Twin Ver.                FIFTY FIFTY
# 4   All Of The Girls You Loved Before               Taylor Swift
# 5                            Reminder                 The Weeknd
# 6                            Nonsense          Sabrina Carpenter
# 7                  Boy's a Liar Pt. 2  PinkPantheress, Ice Spice
# 8                             Flowers                Miley Cyrus
# 9                          Those Eyes                   New West
# 10                               Uhaw                      Dilaw
# 11                              LIMBO                      keshi
# 12                              Tally                  BLACKPINK
# 13                       Cruel Summer               Taylor Swift
# 14                          Enchanted               Taylor Swift
# 15                          panaginip                      iluna
# 16                              Style               Taylor Swift
# 17                        Ikaw Pa Rin                       mrld
# 18               Say You Won't Let Go               James Arthur
# 19                             lowkey                       NIKI
# 20                              Ghost              Justin Bieber
# 21                           cardigan               Taylor Swift
# 22                      Lavender Haze               Taylor Swift
# 23            Come Inside Of My Heart               IV Of Spades
# 24                            Tadhana             Up Dharma Down
# 25                               Sino             Unique Salonga
# 26                               Higa                Arthur Nery
# 27                            Players                  Coi Leray
# 28                         Pink Venom                  BLACKPINK
# 29                        Blank Space               Taylor Swift
# 30             Is There Someone Else?                 The Weeknd
# 31                              Lover               Taylor Swift
# 32                             Ligaya                       mrld
# 33                   Set Me Free Pt.2                      Jimin
# 34                              Cupid                FIFTY FIFTY
# 35                  Paninindigan Kita                    Ben&Ben
# 36                       Kathang Isip                    Ben&Ben
# 37                 Nahuhulog Na Sa'yo             Noah Alejandre
# 38                      Night Changes              One Direction
# 39                          Araw-Araw                    Ben&Ben
# 40               Bumalik Ka Na Sa'kin           Silent Sanctuary
# 41                               NVMD               Denise Julia
# 42                         Like Crazy                      Jimin
# 43                                 YK                   Cean Jr.
# 44                         Dandelions                    Ruth B.
# 45         Sa Susunod na Habang Buhay                    Ben&Ben
# 46                                BMW            Because, Leslie
# 47                             august               Taylor Swift
# 48                      I Love You So                The Walters
# 49                              Mundo               IV Of Spades
# 50                   Every Summertime                       NIKI
# 30       199111  ...   48.777778      7.0      7.0      7.0      7.0      7.0
# 31       221307  ...   28.714286      7.0      7.0      7.0      7.0      8.0
# 32       248800  ...   33.015873      7.0      9.0      7.0      8.0      9.0
# 33       200930  ...   37.047619      7.0      4.0      NaN      NaN      NaN
# 34       174253  ...   67.920635      7.0      8.0      8.0      9.0      9.0
# 35       312234  ...   47.126984      7.0      8.0      8.0      8.0      8.0
# 36       318814  ...   47.126984      7.0      7.0      7.0      7.0      7.0
# 37       217037  ...   15.714286      7.0      7.0      7.0      7.0      7.0
# 38       226600  ...   54.841270      7.0      7.0      6.0      6.0      6.0
# 39       313952  ...   47.126984      7.0      7.0      6.0      7.0      7.0
# 40       216387  ...   42.047619      7.0      5.0      4.0      4.0      6.0
# 41       181224  ...   16.634921      7.0      6.0      6.0      6.0      7.0
# 42       212241  ...   37.047619      7.0      7.0      6.0      4.0      4.0
# 43       170263  ...    8.111111      7.0      6.0      6.0      5.0      5.0
# 44       233720  ...   18.952381      7.0      7.0      6.0      6.0      7.0
# 45       288189  ...   47.126984      6.0      6.0      6.0      6.0      7.0
# 46       168205  ...   81.888889      6.0      6.0      5.0      6.0      6.0
# 47       261923  ...   28.714286      6.0      6.0      6.0      6.0      6.0
# 48       160240  ...   10.634921      6.0      6.0      6.0      6.0      6.0
# 49       349713  ...   44.984127      6.0      7.0      7.0      7.0      8.0
# 50       215687  ...   13.047619      6.0      6.0      6.0      5.0      5.0
# 51       236413  ...   28.714286      NaN      NaN      NaN      NaN      NaN
# 52       246667  ...   28.428571      6.0      6.0      7.0      9.0      9.0
# 53       162029  ...    9.126984      6.0      6.0      6.0      6.0      6.0
# 54       194207  ...   28.714286      6.0      6.0      6.0      6.0      6.0
#
#     stream6  stream7  stream8  stream9
# 0      10.0     10.0     10.0     10.0
# 1      10.0     10.0     10.0     10.0
# 2      10.0     10.0     10.0     10.0
# 3      10.0     10.0     10.0     10.0
# 4       9.0      9.0      9.0      9.0
# 5       9.0      9.0      9.0      9.0
# 6       9.0      9.0     10.0     10.0
# 7       9.0      9.0      9.0      9.0
# 8       9.0      9.0      9.0      9.0
# 9       9.0      9.0      9.0      9.0
# 10      9.0      9.0      9.0      9.0
# 11      9.0      9.0      9.0      9.0
# 12     10.0     10.0     10.0      9.0
# 13     10.0     10.0     10.0     10.0
# 14      9.0     10.0      9.0      9.0
# 15      9.0      9.0      9.0      9.0
# 16      9.0      9.0      9.0      9.0
# 17      9.0      7.0      7.0      7.0
# 18      7.0      7.0      7.0      7.0
# 19      7.0      8.0      9.0      9.0
# 20      7.0      7.0      8.0      8.0
# 21      9.0      9.0      9.0      9.0
# 22      6.0      6.0      6.0      5.0
# 23      8.0      8.0      8.0      8.0
# 24      9.0      9.0      9.0      9.0
# 25      8.0      9.0      9.0      8.0
# 26      9.0      8.0      8.0      8.0
# 27      6.0      5.0      4.0      4.0
# 28      6.0      5.0      5.0      5.0
# 29      7.0      8.0      8.0      8.0
# 30      9.0      9.0      9.0      9.0
# 31      7.0      8.0      8.0      8.0
# 32      9.0      9.0      8.0      8.0
# 33      NaN      NaN      NaN      NaN
# 34      8.0      7.0      6.0      5.0
# 35      8.0      8.0      7.0      7.0
# 36      8.0      7.0      8.0      7.0
# 37      5.0      5.0      5.0      4.0
# 38      6.0      7.0      7.0      8.0
# 39      7.0      7.0      7.0      7.0
# 40      7.0      7.0      8.0      7.0
# 41      6.0      5.0      5.0      5.0
# 42      NaN      NaN      4.0      NaN
# 43      5.0      6.0      7.0      7.0
# 44      7.0      7.0      7.0      7.0
# 45      7.0      6.0      6.0      7.0
# 46      9.0      9.0      9.0      9.0
# 47      6.0      6.0      7.0      7.0
# 48      6.0      7.0      7.0      7.0
# 49      8.0      7.0      8.0      7.0
# 50      5.0      6.0      6.0      6.0
# 51      NaN      NaN      NaN      NaN
# 52      9.0      9.0      9.0      9.0
# 53      7.0      7.0      6.0      5.0
# 54      6.0      6.0      7.0      7.0
#
# [55 rows x 22 columns]

# %%
week10 = pd.read_csv('week10 - streamcategory.csv')

week10.rename(columns={"track_name": "title"}, inplace=True)
week10.rename(columns={"artist_names": "artist/s"}, inplace=True)

data = pd.merge(data, week10[['title', 'artist/s', 'stream_category']], how='left', on=['title', 'artist/s'])

print(data)
# Out:
#                                 title                   artist/s  \
# 0                 Uhaw (Tayong Lahat)                      Dilaw
# 1                             Elevate                Jeff Grecia
# 2                              Snooze                        SZA
# 3                   Cupid - Twin Ver.                FIFTY FIFTY
# 4   All Of The Girls You Loved Before               Taylor Swift
# 5                            Reminder                 The Weeknd
# 6                            Nonsense          Sabrina Carpenter
# 7                  Boy's a Liar Pt. 2  PinkPantheress, Ice Spice
# 8                             Flowers                Miley Cyrus
# 9                          Those Eyes                   New West
# 10                               Uhaw                      Dilaw
# 11                              LIMBO                      keshi
# 12                              Tally                  BLACKPINK
# 13                       Cruel Summer               Taylor Swift
# 14                          Enchanted               Taylor Swift
# 15                          panaginip                      iluna
# 16                              Style               Taylor Swift
# 17                        Ikaw Pa Rin                       mrld
# 18               Say You Won't Let Go               James Arthur
# 19                             lowkey                       NIKI
# 20                              Ghost              Justin Bieber
# 21                           cardigan               Taylor Swift
# 22                      Lavender Haze               Taylor Swift
# 23            Come Inside Of My Heart               IV Of Spades
# 24                            Tadhana             Up Dharma Down
# 25                               Sino             Unique Salonga
# 26                               Higa                Arthur Nery
# 27                            Players                  Coi Leray
# 28                         Pink Venom                  BLACKPINK
# 29                        Blank Space               Taylor Swift
# 30             Is There Someone Else?                 The Weeknd
# 31                              Lover               Taylor Swift
# 32                             Ligaya                       mrld
# 33                   Set Me Free Pt.2                      Jimin
# 34                              Cupid                FIFTY FIFTY
# 35                  Paninindigan Kita                    Ben&Ben
# 36                       Kathang Isip                    Ben&Ben
# 37                 Nahuhulog Na Sa'yo             Noah Alejandre
# 38                      Night Changes              One Direction
# 39                          Araw-Araw                    Ben&Ben
# 40               Bumalik Ka Na Sa'kin           Silent Sanctuary
# 41                               NVMD               Denise Julia
# 42                         Like Crazy                      Jimin
# 43                                 YK                   Cean Jr.
# 44                         Dandelions                    Ruth B.
# 38         0.672    8    -7.747       0.0353    0.1150   0.3700  120.001
# 39         0.475   11    -8.390       0.0295    0.2340   0.2240  140.903
# 40         0.630    2    -8.581       0.0400    0.0749   0.7920  123.995
# 41         0.758    6    -4.533       0.1080    0.0902   0.4240   97.977
# 42         0.629    7    -5.445       0.0419    0.3570   0.3620  120.001
# 43         0.717    6    -7.872       0.0349    0.0721   0.5380  118.005
# 44         0.609    1    -2.958       0.0259    0.0864   0.4540  116.959
# 45         0.311    2    -8.889       0.0320    0.1140   0.2740  177.158
# 46         0.758    1    -9.799       0.0485    0.0990   0.2380  117.048
# 47         0.532    5    -9.208       0.0331    0.0925   0.4030   89.937
# 48         0.575   10    -4.891       0.0358    0.1150   0.4660   75.977
# 49         0.705    6    -8.900       0.0376    0.0735   0.4810  140.031
# 50         0.628    6    -4.227       0.0424    0.0978   0.7230   78.996
# 51         0.615    9    -6.719       0.0386    0.0607   0.1930  135.917
# 52         0.630    9    -7.140       0.0290    0.1220   0.5010  134.774
# 53         0.843    9    -8.114       0.3250    0.5770   0.4450   71.007
# 54         0.696    2   -10.289       0.0656    0.1250   0.3800  120.041
#
#     duration_ms  ... stream1  stream2  stream3  stream4  stream5  stream6  \
# 0        241186  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 1        218651  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 2        201800  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 3        174253  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 4        221407  ...    10.0     10.0     10.0     10.0     10.0      9.0
# 5        218880  ...    10.0     10.0      9.0      9.0      9.0      9.0
# 6        163648  ...    10.0     10.0     10.0      9.0      9.0      9.0
# 7        131013  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 8        200455  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 9        220750  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 10       267049  ...     9.0     10.0     10.0      9.0      9.0      9.0
# 11       212785  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 12       184248  ...     9.0      9.0      9.0     10.0     10.0     10.0
# 13       178427  ...     9.0      9.0      9.0      9.0     10.0     10.0
# 14       352200  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 15       332406  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 16       231000  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 17       191009  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 18       211467  ...     9.0      9.0      8.0      7.0      7.0      7.0
# 19       171356  ...     9.0      9.0      8.0      7.0      7.0      7.0
# 20       153190  ...     9.0      9.0      8.0      7.0      7.0      7.0
# 21       239560  ...     9.0      8.0      9.0      9.0      9.0      9.0
# 22       202396  ...     8.0      7.0      7.0      7.0      7.0      6.0
# 23       246396  ...     8.0      8.0      9.0      8.0      8.0      8.0
# 24       222447  ...     8.0      8.0      8.0      9.0      9.0      9.0
# 25       280427  ...     8.0      7.0      7.0      8.0      8.0      8.0
# 26       245760  ...     8.0      8.0      7.0      9.0      9.0      9.0
# 27       139560  ...     8.0      7.0      6.0      7.0      6.0      6.0
# 28       186964  ...     8.0      7.0      6.0      6.0      7.0      6.0
# 29       231827  ...     7.0      7.0      7.0      7.0      7.0      7.0
# 30       199111  ...     7.0      7.0      7.0      7.0      7.0      9.0
# 31       221307  ...     7.0      7.0      7.0      7.0      8.0      7.0
# 32       248800  ...     7.0      9.0      7.0      8.0      9.0      9.0
# 33       200930  ...     7.0      4.0      NaN      NaN      NaN      NaN
# 34       174253  ...     7.0      8.0      8.0      9.0      9.0      8.0
# 35       312234  ...     7.0      8.0      8.0      8.0      8.0      8.0
# 36       318814  ...     7.0      7.0      7.0      7.0      7.0      8.0
# 37       217037  ...     7.0      7.0      7.0      7.0      7.0      5.0
# 38       226600  ...     7.0      7.0      6.0      6.0      6.0      6.0
# 39       313952  ...     7.0      7.0      6.0      7.0      7.0      7.0
# 40       216387  ...     7.0      5.0      4.0      4.0      6.0      7.0
# 41       181224  ...     7.0      6.0      6.0      6.0      7.0      6.0
# 42       212241  ...     7.0      7.0      6.0      4.0      4.0      NaN
# 43       170263  ...     7.0      6.0      6.0      5.0      5.0      5.0
# 44       233720  ...     7.0      7.0      6.0      6.0      7.0      7.0
# 45       288189  ...     6.0      6.0      6.0      6.0      7.0      7.0
# 46       168205  ...     6.0      6.0      5.0      6.0      6.0      9.0
# 47       261923  ...     6.0      6.0      6.0      6.0      6.0      6.0
# 48       160240  ...     6.0      6.0      6.0      6.0      6.0      6.0
# 49       349713  ...     6.0      7.0      7.0      7.0      8.0      8.0
# 50       215687  ...     6.0      6.0      6.0      5.0      5.0      5.0
# 51       236413  ...     NaN      NaN      NaN      NaN      NaN      NaN
# 52       246667  ...     6.0      6.0      7.0      9.0      9.0      9.0
# 53       162029  ...     6.0      6.0      6.0      6.0      6.0      7.0
# 54       194207  ...     6.0      6.0      6.0      6.0      6.0      6.0
#
#     stream7  stream8  stream9  stream_category
# 0      10.0     10.0     10.0             10.0
# 1      10.0     10.0     10.0             10.0
# 2      10.0     10.0     10.0             10.0
# 3      10.0     10.0     10.0             10.0
# 4       9.0      9.0      9.0              9.0
# 5       9.0      9.0      9.0              9.0
# 6       9.0     10.0     10.0             10.0
# 7       9.0      9.0      9.0              9.0
# 8       9.0      9.0      9.0              9.0
# 9       9.0      9.0      9.0              9.0
# 10      9.0      9.0      9.0              9.0
# 11      9.0      9.0      9.0              9.0
# 12     10.0     10.0      9.0              9.0
# 13     10.0     10.0     10.0             10.0
# 14     10.0      9.0      9.0             10.0
# 15      9.0      9.0      9.0              9.0
# 16      9.0      9.0      9.0              9.0
# 17      7.0      7.0      7.0              6.0
# 18      7.0      7.0      7.0              7.0
# 19      8.0      9.0      9.0              9.0
# 20      7.0      8.0      8.0              7.0
# 21      9.0      9.0      9.0              9.0
# 22      6.0      6.0      5.0              9.0
# 23      8.0      8.0      8.0              8.0
# 24      9.0      9.0      9.0              9.0
# 25      9.0      9.0      8.0              8.0
# 26      8.0      8.0      8.0              7.0
# 27      5.0      4.0      4.0              4.0
# 28      5.0      5.0      5.0              4.0
# 29      8.0      8.0      8.0              8.0
# 30      9.0      9.0      9.0              9.0
# 31      8.0      8.0      8.0              9.0
# 32      9.0      8.0      8.0              7.0
# 33      NaN      NaN      NaN              NaN
# 34      7.0      6.0      5.0              5.0
# 35      8.0      7.0      7.0              7.0
# 36      7.0      8.0      7.0              7.0
# 37      5.0      5.0      4.0              4.0
# 38      7.0      7.0      8.0              8.0
# 39      7.0      7.0      7.0              7.0
# 40      7.0      8.0      7.0              6.0
# 41      5.0      5.0      5.0              5.0
# 42      NaN      4.0      NaN              NaN
# 43      6.0      7.0      7.0              6.0
# 44      7.0      7.0      7.0              7.0
# 45      6.0      6.0      7.0              7.0
# 46      9.0      9.0      9.0              8.0
# 47      6.0      7.0      7.0              8.0
# 48      7.0      7.0      7.0              6.0
# 49      7.0      8.0      7.0              7.0
# 50      6.0      6.0      6.0              6.0
# 51      NaN      NaN      NaN              NaN
# 52      9.0      9.0      9.0              9.0
# 53      7.0      6.0      5.0              5.0
# 54      6.0      7.0      7.0              9.0
#
# [55 rows x 23 columns]

# %%
new_data = data.iloc[:50]
new_data['stream2'] = new_data['stream2'].fillna(1)
new_data['stream3'] = new_data['stream3'].fillna(1)
new_data['stream4'] = new_data['stream4'].fillna(1)
new_data['stream5'] = new_data['stream5'].fillna(1)
new_data['stream6'] = new_data['stream6'].fillna(1)
new_data['stream7'] = new_data['stream7'].fillna(1)
new_data['stream8'] = new_data['stream8'].fillna(1)
new_data['stream9'] = new_data['stream9'].fillna(1)
new_data['stream_category'] = new_data['stream_category'].fillna(1)
new_data
# Out:
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream2'] = new_data['stream2'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream3'] = new_data['stream3'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream4'] = new_data['stream4'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream5'] = new_data['stream5'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream6'] = new_data['stream6'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream7'] = new_data['stream7'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream8'] = new_data['stream8'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream9'] = new_data['stream9'].fillna(1)
# C:\Users\angel\AppData\Local\Temp/ipykernel_28580/2408792636.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['stream_category'] = new_data['stream_category'].fillna(1)
#                                 title                   artist/s  \
# 0                 Uhaw (Tayong Lahat)                      Dilaw
# 1                             Elevate                Jeff Grecia
# 2                              Snooze                        SZA
# 3                   Cupid - Twin Ver.                FIFTY FIFTY
# 4   All Of The Girls You Loved Before               Taylor Swift
# 5                            Reminder                 The Weeknd
# 6                            Nonsense          Sabrina Carpenter
# 7                  Boy's a Liar Pt. 2  PinkPantheress, Ice Spice
# 8                             Flowers                Miley Cyrus
# 9                          Those Eyes                   New West
# 10                               Uhaw                      Dilaw
# 11                              LIMBO                      keshi
# 12                              Tally                  BLACKPINK
# 13                       Cruel Summer               Taylor Swift
# 14                          Enchanted               Taylor Swift
# 15                          panaginip                      iluna
# 16                              Style               Taylor Swift
# 17                        Ikaw Pa Rin                       mrld
# 18               Say You Won't Let Go               James Arthur
# 19                             lowkey                       NIKI
# 20                              Ghost              Justin Bieber
# 21                           cardigan               Taylor Swift
# 22                      Lavender Haze               Taylor Swift
# 23            Come Inside Of My Heart               IV Of Spades
# 24                            Tadhana             Up Dharma Down
# 25                               Sino             Unique Salonga
# 26                               Higa                Arthur Nery
# 27                            Players                  Coi Leray
# 28                         Pink Venom                  BLACKPINK
# 29                        Blank Space               Taylor Swift
# 30             Is There Someone Else?                 The Weeknd
# 33         0.585    0    -4.165       0.0565    0.1240   0.5640  132.090
# 34         0.774    2    -8.200       0.0328    0.4000   0.9610  120.023
# 35         0.624    4    -9.288       0.0308    0.3570   0.7500  113.204
# 36         0.491   10    -8.580       0.0301    0.1520   0.2950  126.921
# 37         0.765    6    -7.549       0.0317    0.1040   0.6390  107.930
# 38         0.672    8    -7.747       0.0353    0.1150   0.3700  120.001
# 39         0.475   11    -8.390       0.0295    0.2340   0.2240  140.903
# 40         0.630    2    -8.581       0.0400    0.0749   0.7920  123.995
# 41         0.758    6    -4.533       0.1080    0.0902   0.4240   97.977
# 42         0.629    7    -5.445       0.0419    0.3570   0.3620  120.001
# 43         0.717    6    -7.872       0.0349    0.0721   0.5380  118.005
# 44         0.609    1    -2.958       0.0259    0.0864   0.4540  116.959
# 45         0.311    2    -8.889       0.0320    0.1140   0.2740  177.158
# 46         0.758    1    -9.799       0.0485    0.0990   0.2380  117.048
# 47         0.532    5    -9.208       0.0331    0.0925   0.4030   89.937
# 48         0.575   10    -4.891       0.0358    0.1150   0.4660   75.977
# 49         0.705    6    -8.900       0.0376    0.0735   0.4810  140.031
#
#     duration_ms  ... stream1  stream2  stream3  stream4  stream5  stream6  \
# 0        241186  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 1        218651  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 2        201800  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 3        174253  ...    10.0     10.0     10.0     10.0     10.0     10.0
# 4        221407  ...    10.0     10.0     10.0     10.0     10.0      9.0
# 5        218880  ...    10.0     10.0      9.0      9.0      9.0      9.0
# 6        163648  ...    10.0     10.0     10.0      9.0      9.0      9.0
# 7        131013  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 8        200455  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 9        220750  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 10       267049  ...     9.0     10.0     10.0      9.0      9.0      9.0
# 11       212785  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 12       184248  ...     9.0      9.0      9.0     10.0     10.0     10.0
# 13       178427  ...     9.0      9.0      9.0      9.0     10.0     10.0
# 14       352200  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 15       332406  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 16       231000  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 17       191009  ...     9.0      9.0      9.0      9.0      9.0      9.0
# 18       211467  ...     9.0      9.0      8.0      7.0      7.0      7.0
# 19       171356  ...     9.0      9.0      8.0      7.0      7.0      7.0
# 20       153190  ...     9.0      9.0      8.0      7.0      7.0      7.0
# 21       239560  ...     9.0      8.0      9.0      9.0      9.0      9.0
# 22       202396  ...     8.0      7.0      7.0      7.0      7.0      6.0
# 23       246396  ...     8.0      8.0      9.0      8.0      8.0      8.0
# 24       222447  ...     8.0      8.0      8.0      9.0      9.0      9.0
# 25       280427  ...     8.0      7.0      7.0      8.0      8.0      8.0
# 26       245760  ...     8.0      8.0      7.0      9.0      9.0      9.0
# 27       139560  ...     8.0      7.0      6.0      7.0      6.0      6.0
# 28       186964  ...     8.0      7.0      6.0      6.0      7.0      6.0
# 29       231827  ...     7.0      7.0      7.0      7.0      7.0      7.0
# 30       199111  ...     7.0      7.0      7.0      7.0      7.0      9.0
# 31       221307  ...     7.0      7.0      7.0      7.0      8.0      7.0
# 32       248800  ...     7.0      9.0      7.0      8.0      9.0      9.0
# 33       200930  ...     7.0      4.0      1.0      1.0      1.0      1.0
# 34       174253  ...     7.0      8.0      8.0      9.0      9.0      8.0
# 35       312234  ...     7.0      8.0      8.0      8.0      8.0      8.0
# 36       318814  ...     7.0      7.0      7.0      7.0      7.0      8.0
# 37       217037  ...     7.0      7.0      7.0      7.0      7.0      5.0
# 38       226600  ...     7.0      7.0      6.0      6.0      6.0      6.0
# 39       313952  ...     7.0      7.0      6.0      7.0      7.0      7.0
# 40       216387  ...     7.0      5.0      4.0      4.0      6.0      7.0
# 41       181224  ...     7.0      6.0      6.0      6.0      7.0      6.0
# 42       212241  ...     7.0      7.0      6.0      4.0      4.0      1.0
# 43       170263  ...     7.0      6.0      6.0      5.0      5.0      5.0
# 44       233720  ...     7.0      7.0      6.0      6.0      7.0      7.0
# 45       288189  ...     6.0      6.0      6.0      6.0      7.0      7.0
# 46       168205  ...     6.0      6.0      5.0      6.0      6.0      9.0
# 47       261923  ...     6.0      6.0      6.0      6.0      6.0      6.0
# 48       160240  ...     6.0      6.0      6.0      6.0      6.0      6.0
# 49       349713  ...     6.0      7.0      7.0      7.0      8.0      8.0
#
#     stream7  stream8  stream9  stream_category
# 0      10.0     10.0     10.0             10.0
# 1      10.0     10.0     10.0             10.0
# 2      10.0     10.0     10.0             10.0
# 3      10.0     10.0     10.0             10.0
# 4       9.0      9.0      9.0              9.0
# 5       9.0      9.0      9.0              9.0
# 6       9.0     10.0     10.0             10.0
# 7       9.0      9.0      9.0              9.0
# 8       9.0      9.0      9.0              9.0
# 9       9.0      9.0      9.0              9.0
# 10      9.0      9.0      9.0              9.0
# 11      9.0      9.0      9.0              9.0
# 12     10.0     10.0      9.0              9.0
# 13     10.0     10.0     10.0             10.0
# 14     10.0      9.0      9.0             10.0
# 15      9.0      9.0      9.0              9.0
# 16      9.0      9.0      9.0              9.0
# 17      7.0      7.0      7.0              6.0
# 18      7.0      7.0      7.0              7.0
# 19      8.0      9.0      9.0              9.0
# 20      7.0      8.0      8.0              7.0
# 21      9.0      9.0      9.0              9.0
# 22      6.0      6.0      5.0              9.0
# 23      8.0      8.0      8.0              8.0
# 24      9.0      9.0      9.0              9.0
# 25      9.0      9.0      8.0              8.0
# 26      8.0      8.0      8.0              7.0
# 27      5.0      4.0      4.0              4.0
# 28      5.0      5.0      5.0              4.0
# 29      8.0      8.0      8.0              8.0
# 30      9.0      9.0      9.0              9.0
# 31      8.0      8.0      8.0              9.0
# 32      9.0      8.0      8.0              7.0
# 33      1.0      1.0      1.0              1.0
# 34      7.0      6.0      5.0              5.0
# 35      8.0      7.0      7.0              7.0
# 36      7.0      8.0      7.0              7.0
# 37      5.0      5.0      4.0              4.0
# 38      7.0      7.0      8.0              8.0
# 39      7.0      7.0      7.0              7.0
# 40      7.0      8.0      7.0              6.0
# 41      5.0      5.0      5.0              5.0
# 42      1.0      4.0      1.0              1.0
# 43      6.0      7.0      7.0              6.0
# 44      7.0      7.0      7.0              7.0
# 45      6.0      6.0      7.0              7.0
# 46      9.0      9.0      9.0              8.0
# 47      6.0      7.0      7.0              8.0
# 48      7.0      7.0      7.0              6.0
# 49      7.0      8.0      7.0              7.0
#
# [50 rows x 23 columns]

# %%
print(new_data.isnull().sum())
# Out:
# title              0
# artist/s           0
# danceability       0
# key                0
# loudness           0
# speechiness        0
# liveness           0
# valence            0
# tempo              0
# duration_ms        0
# artist_collab      0
# chart_history      0
# mean_trends        0
# stream1            0
# stream2            0
# stream3            0
# stream4            0
# stream5            0
# stream6            0
# stream7            0
# stream8            0
# stream9            0
# stream_category    0
# dtype: int64

# %%
print(new_data.dtypes)
# Out:
# title               object
# artist/s            object
# danceability       float64
# key                  int64
# loudness           float64
# speechiness        float64
# liveness           float64
# valence            float64
# tempo              float64
# duration_ms          int64
# artist_collab       object
# chart_history        int64
# mean_trends        float64
# stream1            float64
# stream2            float64
# stream3            float64
# stream4            float64
# stream5            float64
# stream6            float64
# stream7            float64
# stream8            float64
# stream9            float64
# stream_category    float64
# dtype: object

# %%
new_data = new_data.astype({'duration_ms':'float', 'chart_history':'float','key':'float','artist_collab':'float'})
print(new_data.dtypes)
# Out:
# title               object
# artist/s            object
# danceability       float64
# key                float64
# loudness           float64
# speechiness        float64
# liveness           float64
# valence            float64
# tempo              float64
# duration_ms        float64
# artist_collab      float64
# chart_history      float64
# mean_trends        float64
# stream1            float64
# stream2            float64
# stream3            float64
# stream4            float64
# stream5            float64
# stream6            float64
# stream7            float64
# stream8            float64
# stream9            float64
# stream_category    float64
# dtype: object

# %%
# temp.to_csv('complete_data_term2run.csv', encoding='utf-8')

# %%
# dataaaaa hereeee

# %%
# split data
new_data = new_data.drop(columns=['title', 'artist/s'])
data2 = new_data
X_data =  new_data.values[:,:-1]
y_data = new_data.values[:,-1]

print(X_data.shape)
print(y_data.shape)
# Out:
# (50, 20)
# (50,)

# %%
# y_data

# %% [markdown]
# SEM HERE:

# %%
# try normalizing non-ordinal variables (no onehot encode (before may 30 2023))
from sklearn.preprocessing import StandardScaler
cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 
                'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 
                'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']
data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])
# print(data)

# %%
# try normalizing non-ordinal variables (may 30 2023)
from sklearn.preprocessing import StandardScaler
cols_to_norm = ['danceability', 'speechiness', 'liveness', 'duration_ms', 'mean_trends', 'song_familiarity', 
                'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 
                'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']
data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])
# print(data)

# %%
# cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 
#                 'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 
#                 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']

# # copy the data
# data_min_max_scaled = data.copy()

# # apply normalization techniques
# for column in cols_to_norm:
# 	data_min_max_scaled[column] = (data_min_max_scaled[column] - data_min_max_scaled[column].min()) / (data_min_max_scaled[column].max() - data_min_max_scaled[column].min())	

# # view normalized data
# # print(data_min_max_scaled)

# %%
# cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 
#                 'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 
#                 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']

# # copy the data
# data_max_scaled = data.copy()
  
# # apply normalization techniques
# for column in cols_to_norm:
#     data_max_scaled[column] = data_max_scaled[column]  / data_max_scaled[column].abs().max()

# %%
print(sem.efa.explore_cfa_model(data))
# Out:
# WARNING:root:Fisher Information Matrix is not PD.Moore-Penrose inverse will be used instead of Cholesky decomposition. See 10.1109/TSP.2012.2208105.
# eta1 =~ stream7 + stream8 + stream9 + stream6 + stream5 + stream_category
# eta2 =~ bad_good + unpleasant_pleasant + distasteful_tasty + tasteless_tasteful + share_friends + listen_similar + add_playlist + untalented_talented
# eta3 =~ danceability + valence + duration_ms
# eta4 =~ forgettable_memorable + boring_interesting + unimaginative_creative + dull_exciting
# eta6 =~ liveness + danceability
# eta8 =~ stream5 + stream6 + stream3 + stream4 + stream2 + stream1
# eta10 =~ song_familiarity + forgettable_memorable + artist_familiarity

# %%
# # model intrinsic extrinsic crowdsource
# mod = """
# eta3 =~ stream8 + stream9 + stream7 + stream6 + stream_category + stream5 + artist_familiarity
# eta4 =~ bad_good + share_friends + unpleasant_pleasant + tasteless_tasteful + distasteful_tasty + boring_interesting + listen_similar + add_playlist + unimaginative_creative + untalented_talented + forgettable_memorable + dull_exciting + song_familiarity
# eta5 =~ valence + duration_ms + danceability + loudness
# eta6 =~ song_familiarity + forgettable_memorable + artist_familiarity
# eta7 =~ boring_interesting + dull_exciting + chart_history + loudness
# eta8 =~ stream5 + stream6 + stream3 + stream4 + stream2 + stream1

# DEFINE(ordinal) stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
#       """

# %%
# # model intrinsic extrinsic crowdsource before may 30
# mod = """
# chart_success =~ stream1 + stream2 + stream3 + stream4 + stream5 + stream6 + stream6 + stream7 + stream8 + stream9 + stream_category
# intrinsic =~ danceability + key + loudness + speechiness + liveness + valence + tempo + duration_ms
# extrinsic =~ music_label + artist_collab + chart_history + mean_trends
# crowdsource =~ song_familiarity + artist_familiarity + bad_good + distasteful_tasty + dull_exciting + tasteless_tasteful + unimaginative_creative + untalented_talented + unpleasant_pleasant + forgettable_memorable + boring_interesting + listen_similar + share_friends + add_playlist

# chart_success ~ intrinsic + extrinsic + crowdsource

# DEFINE(ordinal) key music_label artist_collab stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
#       """

# %%
# model intrinsic extrinsic crowdsource (may 30)
mod = """
chart_success =~ stream1 + stream2 + stream3 + stream4 + stream5 + stream6 + stream6 + stream7 + stream8 + stream9 + stream_category
intrinsic =~ danceability + key_0 + key_1 + key_2 + key_3 + key_4 + key_5 + key_6 + key_7 + key_8 + key_9 + key_10 + key_11 + loudness + speechiness + liveness + valence + tempo + duration_ms
extrinsic =~ music_label + artist_collab + chart_history + mean_trends
crowdsource =~ song_familiarity + artist_familiarity + bad_good + distasteful_tasty + dull_exciting + tasteless_tasteful + unimaginative_creative + untalented_talented + unpleasant_pleasant + forgettable_memorable + boring_interesting + listen_similar + share_friends + add_playlist

chart_success ~ intrinsic + extrinsic + crowdsource

DEFINE(ordinal) music_label tempo stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
      """

# %%
model = sem.Model(mod)
result = model.fit(data, obj="FIML", solver="SLSQP") #can change obj and solver
print(result)
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\semopy\polycorr.py:147: RuntimeWarning: divide by zero encountered in log
#   return -sum(pdf + np.log(sub_pr(ind, rho, z))
# C:\Users\angel\anaconda3\lib\site-packages\semopy\polycorr.py:204: RuntimeWarning: divide by zero encountered in log
#   return -sum(np.log(bivariate_cdf([x_ints[i], y_ints[j]],
# C:\Users\angel\anaconda3\lib\site-packages\semopy\polycorr.py:204: RuntimeWarning: invalid value encountered in double_scalars
#   return -sum(np.log(bivariate_cdf([x_ints[i], y_ints[j]],
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
# Name of objective: FIML
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 0.000
# Number of iterations: 74
# Params: 1.011 1.015 1.031 1.009 1.010 0.995 0.986 0.960 0.944 0.109 0.105 0.009 0.047 0.136 0.074 0.154 0.100 0.077 0.078 0.099 0.243 1.158 -0.231 0.212 0.492 4.240 -0.065 0.101 0.443 -0.045 -0.088 0.941 0.964 0.630 0.867 0.823 0.819 0.938 0.733 0.731 0.939 0.887 0.915 -10.237 11.317 1.351 0.600 0.167 0.387 71.934 0.167 0.163 0.163 0.562 0.163 0.694 0.636 2.104 0.166 0.334 0.163 1.595 0.163 0.166 2.175 0.782 0.163 0.163 2.340 2.655 0.537 0.163 1.233 0.166 0.163 6.175 0.670 0.163 0.163 0.402 0.417 0.163 0.232 0.167 0.457 0.857 1.777 0.485 0.167 0.502 2.101 1.683 0.163 1.074 2.426 0.781 1.070 0.479 2.200 4.120

# %%
sem_all_pd = model.inspect()
sem_all_pd
# Out:
#                    lval  op                rval   Estimate   Std. Err  \
# 0         chart_success   ~           intrinsic -10.236758  17.739889
# 1         chart_success   ~           extrinsic  11.317107     8.5106
# 2         chart_success   ~         crowdsource   1.350982   1.634712
# 3               stream1   ~       chart_success   1.000000          -
# 4               stream2   ~       chart_success   1.011486   0.016028
# ..                  ...  ..                 ...        ...        ...
# 99              stream5  ~~             stream5   0.501757   0.114692
# 100  artist_familiarity  ~~  artist_familiarity   2.100533   0.420144
# 101        danceability  ~~        danceability   1.683368   0.330748
# 102               key_6  ~~               key_6   0.163099   0.032457
# 103     stream_category  ~~     stream_category   1.074257   0.226374
#
#       z-value   p-value
# 0   -0.577047  0.563907
# 1    1.329766  0.183595
# 2    0.826434  0.408558
# 3           -         -
# 4    63.10864       0.0
# ..        ...       ...
# 99   4.374828  0.000012
# 100  4.999553  0.000001
# 101  5.089583       0.0
# 102  5.025087  0.000001
# 103  4.745487  0.000002
#
# [104 rows x 7 columns]

# %%
sem_all_pd.to_csv(r'SEM_intrinsicxextrinsicxcrowdsourced_results.csv')

# %%
stats = sem.calc_stats(model)
print(stats.T)
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\semopy\polycorr.py:204: RuntimeWarning: divide by zero encountered in log
#   return -sum(np.log(bivariate_cdf([x_ints[i], y_ints[j]],
# C:\Users\angel\anaconda3\lib\site-packages\semopy\polycorr.py:204: RuntimeWarning: invalid value encountered in double_scalars
#   return -sum(np.log(bivariate_cdf([x_ints[i], y_ints[j]],
# WARNING:root:Sample covariance matrix is not PD. It may indicate that data is bad. Also, it arises often when polychoric/polyserial correlations are used. semopy now will run nearPD subroutines.
#                       Value
# DoF            1.028000e+03
# DoF Baseline   1.081000e+03
# chi2           3.303879e-07
# chi2 p-value   1.000000e+00
# chi2 Baseline  6.035942e+01
# CFI           -7.210588e-03
# GFI            1.000000e+00
# AGFI           1.000000e+00
# NFI            1.000000e+00
# TLI           -5.913876e-02
# RMSEA          0.000000e+00
# AIC           -5.320164e+01
# BIC            1.380007e+02
# LogLik         1.266008e+02

# %%
# g = sem.semplot(model, "pd1.png")
# g

# %%
# model intrinsic extrinsic 
mod2 = """
chart_success =~ stream1 + stream2 + stream3 + stream4 + stream5 + stream6 + stream6 + stream7 + stream8 + stream9 + stream_category
intrinsic =~ danceability + key + loudness + speechiness + liveness + valence + tempo + duration_ms
extrinsic =~ music_label + artist_collab + chart_history + mean_trends

chart_success ~ intrinsic + extrinsic

DEFINE(ordinal) key music_label artist_collab stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
      """

# %%
model2 = sem.Model(mod2)
result2 = model2.fit(data, obj="FIML", solver="SLSQP") #can change obj and solver
print(result2)

# %%
sem_ixe_pd = model2.inspect()
sem_ixe_pd

# %%
sem_ixe_pd.to_csv(r'SEM_intrinsicxextrinsic_results.csv')

# %%
stats2 = sem.calc_stats(model2)
print(stats2.T)

# %%
# g2 = sem.semplot(model2, "pd2.png")
# g2

# %%
# model danceability
mod3 = """
danceability =~ valence + duration_ms + loudness + speechiness + tempo + key + liveness

DEFINE(ordinal) key
      """

# %%
model3 = sem.Model(mod3)
result3 = model3.fit(data) #can change obj and solver
print(result3)

# %%
model3.inspect()

# %%
stats3 = sem.calc_stats(model3)
print(stats3.T)

# %%
# g3 = sem.semplot(model3, "pd3.png")
# g3

# %%
# model valence
mod4 = """
valence =~ danceability + key + loudness + speechiness + liveness + tempo + duration_ms

DEFINE(ordinal) key
      """

# %%
model4 = sem.Model(mod4)
result4 = model4.fit(data) #can change obj and solver
print(result4)

# %%
model4.inspect()

# %%
stats4 = sem.calc_stats(model4)
print(stats4.T)

# %%
# g4 = sem.semplot(model4, "pd4.png")
# g4

# %% [markdown]
# # try recommended path diagram

# %% [markdown]
# SEM STOP HERE

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

# print("X_train: ", X_train.shape)
# print("y_train: ", y_train.shape)
# print("X_test: ", X_test.shape)
# print("y_test: ", y_test.shape)

# %%
# print(X_train)

# %%
# y_train

# %%
# normalizing (read that z-scaling is standardscaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_data = scaler.fit_transform(X_data)
# X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# #convert y values to categorical values
# lab = preprocessing.LabelEncoder()
# y_transformed = lab.fit_transform(y)

# %%
def compute_RMSE(predictions, actual):
    return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
def compute_mae(predictions, actual):
    mae = np.absolute(np.subtract(actual, predictions)).mean()
    return mae
def compute_accuracy(predictions, actual):
    # write code here
    num_correct = np.sum(predictions == actual)
    accuracy = num_correct/len(actual)
    return accuracy*100

# %%
X_data
# Out:
# array([[-1.48922115e-02, -1.15087068e-01,  4.89519299e-01,
#          4.34254444e-01, -5.10513236e-01, -6.75106687e-01,
#          6.77117086e-01,  3.50657837e-01, -2.04124145e-01,
#         -1.24497914e+00,  7.98761074e-01,  1.54514242e+00,
#          1.39636149e+00,  1.32312094e+00,  1.28932877e+00,
#          1.24467833e+00,  1.15444441e+00,  1.14856519e+00,
#          1.17750138e+00,  1.14741702e+00],
#        [ 1.93312939e+00, -1.55367541e+00, -1.38052629e+00,
#          2.21245152e+00, -5.67499583e-01,  7.25672856e-01,
#          3.09724660e-02, -8.27410022e-02, -2.04124145e-01,
#         -1.24497914e+00, -1.24333637e+00,  1.54514242e+00,
#          1.39636149e+00,  1.32312094e+00,  1.28932877e+00,
#          1.24467833e+00,  1.15444441e+00,  1.14856519e+00,
#          1.17750138e+00,  1.14741702e+00],
#        [-5.86512450e-01, -1.15087068e-01,  2.43835637e-01,
#          2.00447526e+00, -4.57748101e-01, -3.00250190e-01,
#          9.85283723e-01, -4.06823711e-01, -2.04124145e-01,
#          7.79377185e-01,  1.73108689e+00,  1.54514242e+00,
#          1.39636149e+00,  1.32312094e+00,  1.28932877e+00,
#          1.24467833e+00,  1.15444441e+00,  1.14856519e+00,
#          1.17750138e+00,  1.14741702e+00],
#        [ 1.09826299e+00,  1.61121895e+00, -2.31555772e-01,
#         -5.66631338e-01,  2.04331931e+00,  1.34714547e+00,
#         -1.52460014e-02, -9.36614606e-01, -2.04124145e-01,
#         -1.24497914e+00,  1.99774580e+00,  1.54514242e+00,
#          1.39636149e+00,  1.32312094e+00,  1.28932877e+00,
#          1.24467833e+00,  1.15444441e+00,  1.14856519e+00,
#          1.17750138e+00,  1.14741702e+00],
#        [ 6.09377259e-01, -9.78240074e-01, -8.04961576e-01,
#         -3.92451215e-01, -2.88899668e-01, -2.80520900e-01,
#         -1.06225531e+00, -2.97369108e-02, -2.04124145e-01,
#          7.79377185e-01, -4.23752377e-01,  1.54514242e+00,
#          1.39636149e+00,  1.32312094e+00,  1.28932877e+00,
#          1.24467833e+00,  6.43628297e-01,  6.49189020e-01,
#          6.37363135e-01,  6.61223365e-01],
#        [ 5.19121432e-01,  7.48065939e-01,  3.76824333e-01,
#          3.59029429e+00,  1.12115359e-01, -3.19979479e-01,
#          1.72708577e+00, -7.83368161e-02, -2.04124145e-01,
#          7.79377185e-01,  8.15427255e-01,  1.54514242e+00,
#          1.39636149e+00,  7.67187774e-01,  7.43003019e-01,
#          6.73724968e-01,  6.43628297e-01,  6.49189020e-01,
#          6.37363135e-01,  6.61223365e-01],
#        [ 7.74846275e-01,  7.48065939e-01,  1.24513689e+00,
#         -5.43234008e-01,  7.45296982e-01,  1.37673940e+00,
#          8.10506543e-01, -1.14057266e+00, -2.04124145e-01,
#         -8.23238239e-01, -1.39235165e+00,  1.54514242e+00,
#          1.39636149e+00,  1.32312094e+00,  7.43003019e-01,
#          6.73724968e-01,  6.43628297e-01,  6.49189020e-01,
#
#          7.79377185e-01,  2.86046579e+00, -1.64071824e+00,
#         -1.31502004e+00, -1.45654490e+00, -8.95974229e-01,
#         -1.03913512e+00,  6.43628297e-01,  6.49189020e-01,
#          6.37363135e-01,  6.61223365e-01],
#        [-7.89588060e-01, -1.15087068e-01, -6.09796348e-01,
#         -5.66631338e-01, -6.42426075e-01, -2.45994644e-01,
#         -1.32437756e+00,  7.49477084e-01, -2.04124145e-01,
#          7.79377185e-01, -4.23752377e-01, -1.64071824e+00,
#         -1.31502004e+00, -9.00611734e-01, -8.95974229e-01,
#         -1.03913512e+00, -8.88820029e-01, -8.48939488e-01,
#         -4.42913365e-01, -3.11163937e-01],
#        [-4.66171347e-01,  1.32350128e+00,  1.25420430e+00,
#         -4.96439348e-01, -4.04982966e-01,  6.47416630e-02,
#         -1.93191975e+00, -1.20611618e+00, -2.04124145e-01,
#         -1.61048792e+00, -1.54038655e+00, -1.64071824e+00,
#         -1.31502004e+00, -9.00611734e-01, -8.95974229e-01,
#         -1.03913512e+00, -8.88820029e-01, -3.49563319e-01,
#         -4.42913365e-01, -3.11163937e-01],
#        [ 5.11600113e-01,  1.72630601e-01, -4.76807652e-01,
#         -4.49644688e-01, -8.42933589e-01,  1.38726498e-01,
#          8.55724045e-01,  2.43787664e+00, -2.04124145e-01,
#          7.79377185e-01,  5.81120347e-01, -1.64071824e+00,
#         -6.37174659e-01, -3.44678565e-01, -3.49648480e-01,
#          1.02771605e-01,  1.32812188e-01, -3.49563319e-01,
#          9.72248850e-02, -3.11163937e-01]])

# %%
# OLD DATA TRIAL W/ EXTRINSIC

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# np.random.seed(1)

# %%
# songs = pd.read_csv('Hits2022.csv')
# labels = pd.read_csv('labels.csv')
# history = pd.read_csv('history.csv')
# week1 = pd.read_csv('week1.csv')
# week2 = pd.read_csv('week2.csv')
# week3 = pd.read_csv('week3.csv')
# week4 = pd.read_csv('week4.csv')
# week5 = pd.read_csv('week5.csv')
# week6 = pd.read_csv('week6.csv')
# week7 = pd.read_csv('week7.csv')
# week8 = pd.read_csv('week8.csv')
# week9 = pd.read_csv('week9.csv')
# week10 = pd.read_csv('week10.csv')

# %%
# # get only first 50 songs
# data = songs.head(50)
# print(data)

# %%
# # merge and clean-ish

# data = pd.merge(data, labels[['title', 'label_category']], how='left', on=['title'])
# data = data.drop(data.columns[[0]], axis = 1) #unnamed column

# history.rename(columns={"history": "history1"}, inplace=True) #rename to avoid suffix
# data = pd.merge(data, history, how='left', left_on=['artist1'], right_on=['artist'])
# data.drop(columns=['artist'], inplace=True)

# history.rename(columns={"history1": "history2"}, inplace=True)
# data = pd.merge(data, history, how='left', left_on=['artist2'], right_on=['artist'])
# data.drop(columns=['artist'], inplace=True)

# history.rename(columns={"history2": "history3"}, inplace=True)
# data = pd.merge(data, history, how='left', left_on=['artist3'], right_on=['artist'])
# data.drop(columns=['artist'], inplace=True)

# data.loc[data.label_category == 'major', 'label_category'] = 10 #check if better 1 and 10 or other values (make sure to understand semopy)
# data.loc[data.label_category == 'indie', 'label_category'] = 5
# data.loc[data.label_category == 'major-indie', 'label_category'] = 1

# data.loc[data.history1 == 'mainstream', 'history1'] = 10
# data.loc[data.history1 == 'newcomer', 'history1'] = 5
# data['history1'] = data['history1'].fillna(1)

# data.loc[data.history2 == 'mainstream', 'history2'] = 10
# data.loc[data.history2 == 'newcomer', 'history2'] = 5
# data['history2'] = data['history2'].fillna(1)

# data.loc[data.history3 == 'mainstream', 'history3'] = 10
# data.loc[data.history3 == 'newcomer', 'history3'] = 5
# data['history3'] = data['history3'].fillna(1)

# print(data)

# %%
# week1.rename(columns={"stream_category": "stream1"}, inplace=True)
# week2.rename(columns={"stream_category": "stream2"}, inplace=True)
# week3.rename(columns={"stream_category": "stream3"}, inplace=True)
# week4.rename(columns={"stream_category": "stream4"}, inplace=True)
# week5.rename(columns={"stream_category": "stream5"}, inplace=True)
# week6.rename(columns={"stream_category": "stream6"}, inplace=True)
# week7.rename(columns={"stream_category": "stream7"}, inplace=True)
# week8.rename(columns={"stream_category": "stream8"}, inplace=True)
# week9.rename(columns={"stream_category": "stream9"}, inplace=True)
# week10.rename(columns={"stream_category": "stream10"}, inplace=True)

# data = pd.merge(data, week1[['title', 'stream1']], how='left', on=['title'])
# data = pd.merge(data, week2[['title', 'stream2']], how='left', on=['title'])
# data = pd.merge(data, week3[['title', 'stream3']], how='left', on=['title'])
# data = pd.merge(data, week4[['title', 'stream4']], how='left', on=['title'])
# data = pd.merge(data, week5[['title', 'stream5']], how='left', on=['title'])
# data = pd.merge(data, week6[['title', 'stream6']], how='left', on=['title'])
# data = pd.merge(data, week7[['title', 'stream7']], how='left', on=['title'])
# data = pd.merge(data, week8[['title', 'stream8']], how='left', on=['title'])
# data = pd.merge(data, week9[['title', 'stream9']], how='left', on=['title'])
# data = pd.merge(data, week10[['title', 'stream10']], how='left', on=['title'])

# print(data)

# %%
# data = data.drop(columns=['artist1', 'artist2', 'artist3', 'popularity']) # 'title', 'artist/s', 
# data = data.drop(columns=['mode', 'time_signature'])
# print(data)

# %%
# print(data.dtypes)

# %%
# # make label_category int (should be no issue because no null)
# data = data.astype({'label_category':'int'})
# # make key and duration float bc not ordinal
# data = data.astype({'key':'float'})
# data = data.astype({'duration_ms':'float'})

# %%
# print(data.dtypes)

# %%
# # split data
# data = data.drop(columns=['title', 'artist/s'])
# X_data =  data.values[:,:-1]
# y_data = data.values[:,-1]

# print(X_data.shape)
# print(y_data.shape)

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

# print("X_train: ", X_train.shape)
# print("y_train: ", y_train.shape)
# print("X_test: ", X_test.shape)
# print("y_test: ", y_test.shape)

# %%
# # normalizing (read that z-scaling is standardscaler)
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# def compute_RMSE(predictions, actual):
#     return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
# def compute_mae(predictions, actual):
#     mae = np.absolute(np.subtract(actual, predictions)).mean()
#     return mae

# %%
# X_train

# %%
# y_train

# %%
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#  RandomForestClassifier?

# %%
rfc = RandomForestClassifier()
rfc.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
hyperparameters = [
        {
        'n_estimators' : [50, 100, 200, 400, 600, 800, 1000, 1200, 1600, 1800],
        'max_depth' : [10, 30, 50, 100, 150, 200, 250, 300, 350, None],
        'min_samples_split' : [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes' : [100, 300, 500, 700, 900, 1100, 1300, None]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsrfc = RandomizedSearchCV(rfc, hyperparameters, random_state=42, n_iter=200, cv=3) #tried adding value for n_iter and cv #n_iter=200 took too long
rsrfc.fit(X_data, y_data)
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   warnings.warn(("The least populated class in y has only %d"
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=200,
#                    param_distributions=[{'max_depth': [10, 30, 50, 100, 150,
#                                                        200, 250, 300, 350,
#                                                        None],
#                                          'max_leaf_nodes': [100, 300, 500, 700,
#                                                             900, 1100, 1300,
#                                                             None],
#                                          'min_samples_split': [2, 4, 6, 10, 15,
#                                                                20],
#                                          'n_estimators': [50, 100, 200, 400,
#                                                           600, 800, 1000, 1200,
#                                                           1600, 1800]}],
#                    random_state=42)

# %%
best_params_rfc = rsrfc.best_params_
best_params_rfc
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 2,
#  'max_leaf_nodes': 900,
#  'max_depth': 250}

# %%
best_model_rfc = rsrfc.best_estimator_

predictions_train_rfc = best_model_rfc.predict(X_data)

train_rmse_rfc = compute_RMSE(predictions_train_rfc, y_data)
print('Training RMSE: {}'.format(train_rmse_rfc))

train_mae_rfc = compute_mae(predictions_train_rfc, y_data)
print('Training MAE: {}'.format(train_mae_rfc))

train_acc = compute_accuracy(predictions_train_rfc, y_data)
print('Training Accuracy: {}'.format(train_acc))

# predictions_test_rfc = best_model_rfc.predict(X_test)

# test_rmse_rfc = compute_RMSE(predictions_test_rfc, y_test)
# print('Test RMSE: {}'.format(test_rmse_rfc))

# test_mae_rfc = compute_mae(predictions_test_rfc, y_test)
# print('Test MAE: {}'.format(test_mae_rfc))

# test_acc = compute_accuracy(predictions_test_rfc, y_test)
# print('Test Accuracy: {}'.format(test_acc))
# Out:
# Training RMSE: 0.0
# Training MAE: 0.0
# Training Accuracy: 100.0

# %%
# SVM

# %%
from sklearn.svm import SVC

# %%
SVC?

# %%
svm = SVC()
svm.get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
hyperparameters = [
        {
        'C' : [0.1, 1, 100, 1000],
        'kernel' : ['rbf', 'poly', 'sigmoid', 'linear'],
        'degree' : [1, 2, 3, 4, 5, 6]
    }
]

# %%
# from sklearn.model_selection import RandomizedSearchCV
rssvm = RandomizedSearchCV(svm, hyperparameters, random_state=42)
rssvm.fit(X_train, y_train)
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# RandomizedSearchCV(estimator=SVC(),
#                    param_distributions=[{'C': [0.1, 1, 100, 1000],
#                                          'degree': [1, 2, 3, 4, 5, 6],
#                                          'kernel': ['rbf', 'poly', 'sigmoid',
#                                                     'linear']}],
#                    random_state=42)

# %%
best_params_svm = rssvm.best_params_
best_params_svm
# Out:
# {'kernel': 'rbf', 'degree': 3, 'C': 1000}

# %%
best_model_svm = rssvm.best_estimator_

predictions_train_svm = best_model_svm.predict(X_train)

train_rmse_svm = compute_RMSE(predictions_train_svm, y_train)
print('Training RMSE: {}'.format(train_rmse_svm))

train_mae_svm = compute_mae(predictions_train_svm, y_train)
print('Training MAE: {}'.format(train_mae_svm))

train_acc = compute_accuracy(predictions_train_svm, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_svm = best_model_svm.predict(X_test)

test_rmse_svm = compute_RMSE(predictions_test_svm, y_test)
print('Test RMSE: {}'.format(test_rmse_svm))

test_mae_svm = compute_mae(predictions_test_svm, y_test)
print('Test MAE: {}'.format(test_mae_svm))

test_acc = compute_accuracy(predictions_test_svm, y_test)
print('Test Accuracy: {}'.format(test_acc))
# Out:
# Training RMSE: 0.3287979746107146
# Training MAE: 0.10810810810810811
# Training Accuracy: 89.1891891891892
# Test RMSE: 0.3922322702763681
# Test MAE: 0.15384615384615385
# Test Accuracy: 84.61538461538461

# %%
# BINARY TREES

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier?

# %%
dt = DecisionTreeClassifier()
dt.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
hyperparameters = [
    {
        'min_impurity_decrease': [0.001, 0.01, 0.05, 0.1, 0.3, 0.5],
        'max_depth': [5, 10, 20, 30],
        'min_samples_split': [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes': [3, 5, 10, 20, 50, 100]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsdt = RandomizedSearchCV(dt, hyperparameters, cv=5, random_state=42, n_iter=50)
rsdt.fit(X_train, y_train)
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:666: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_iter=50,
#                    param_distributions=[{'max_depth': [5, 10, 20, 30],
#                                          'max_leaf_nodes': [3, 5, 10, 20, 50,
#                                                             100],
#                                          'min_impurity_decrease': [0.001, 0.01,
#                                                                    0.05, 0.1,
#                                                                    0.3, 0.5],
#                                          'min_samples_split': [2, 4, 6, 10, 15,
#                                                                20]}],
#                    random_state=42)

# %%
best_params_dt = rsdt.best_params_
best_params_dt
# Out:
# {'min_samples_split': 2,
#  'min_impurity_decrease': 0.1,
#  'max_leaf_nodes': 100,
#  'max_depth': 5}

# %%
best_model_dt = rsdt.best_estimator_

predictions_train_dt = best_model_dt.predict(X_train)

train_rmse_dt = compute_RMSE(predictions_train_dt, y_train)
print('Training RMSE: {}'.format(train_rmse_dt))

train_mae_dt = compute_mae(predictions_train_dt, y_train)
print('Training MAE: {}'.format(train_mae_dt))

train_acc_dt = compute_accuracy(predictions_train_dt, y_train)
print('Training Accuracy: {}'.format(train_acc_dt))

predictions_test_dt = best_model_dt.predict(X_test)

test_rmse_dt = compute_RMSE(predictions_test_dt, y_test)
print('Test RMSE: {}'.format(test_rmse_dt))

test_mae_dt = compute_mae(predictions_test_dt, y_test)
print('Test MAE: {}'.format(test_mae_dt))

test_acc_dt = compute_accuracy(predictions_test_dt, y_test)
print('Test Accuracy: {}'.format(test_acc_dt))
# Out:
# Training RMSE: 0.3287979746107146
# Training MAE: 0.10810810810810811
# Training Accuracy: 89.1891891891892
# Test RMSE: 0.3922322702763681
# Test MAE: 0.15384615384615385
# Test Accuracy: 84.61538461538461

# %% [markdown]
# INTRINSIC AND EXTRINSIC ONLY 3 MODELS

# %%
# split data
data = data2
data = data.drop(columns=['song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist'])
X_data =  data.values[:,:-1]
y_data = data.values[:,-1]

print(X_data.shape)
print(y_data.shape)

# # try normalizing non-ordinal variables
# from sklearn.preprocessing import StandardScaler
# cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 
#                 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']
# data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])
# # print(data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)

# %%
# print(X_train)

# %%
# y_train

# %%
# normalizing (read that z-scaling is standardscaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# #convert y values to categorical values
# lab = preprocessing.LabelEncoder()
# y_transformed = lab.fit_transform(y)

# %%
def compute_RMSE(predictions, actual):
    return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
def compute_mae(predictions, actual):
    mae = np.absolute(np.subtract(actual, predictions)).mean()
    return mae
def compute_accuracy(predictions, actual):
    # write code here
    num_correct = np.sum(predictions == actual)
    accuracy = num_correct/len(actual)
    return accuracy*100

# %%
# OLD DATA TRIAL W/ EXTRINSIC

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# np.random.seed(1)

# %%
# songs = pd.read_csv('Hits2022.csv')
# labels = pd.read_csv('labels.csv')
# history = pd.read_csv('history.csv')
# week1 = pd.read_csv('week1.csv')
# week2 = pd.read_csv('week2.csv')
# week3 = pd.read_csv('week3.csv')
# week4 = pd.read_csv('week4.csv')
# week5 = pd.read_csv('week5.csv')
# week6 = pd.read_csv('week6.csv')
# week7 = pd.read_csv('week7.csv')
# week8 = pd.read_csv('week8.csv')
# week9 = pd.read_csv('week9.csv')
# week10 = pd.read_csv('week10.csv')

# %%
# # get only first 50 songs
# data = songs.head(50)
# print(data)

# %%
# # merge and clean-ish

# data = pd.merge(data, labels[['title', 'label_category']], how='left', on=['title'])
# data = data.drop(data.columns[[0]], axis = 1) #unnamed column

# history.rename(columns={"history": "history1"}, inplace=True) #rename to avoid suffix
# data = pd.merge(data, history, how='left', left_on=['artist1'], right_on=['artist'])
# data.drop(columns=['artist'], inplace=True)

# history.rename(columns={"history1": "history2"}, inplace=True)
# data = pd.merge(data, history, how='left', left_on=['artist2'], right_on=['artist'])
# data.drop(columns=['artist'], inplace=True)

# history.rename(columns={"history2": "history3"}, inplace=True)
# data = pd.merge(data, history, how='left', left_on=['artist3'], right_on=['artist'])
# data.drop(columns=['artist'], inplace=True)

# data.loc[data.label_category == 'major', 'label_category'] = 10 #check if better 1 and 10 or other values (make sure to understand semopy)
# data.loc[data.label_category == 'indie', 'label_category'] = 5
# data.loc[data.label_category == 'major-indie', 'label_category'] = 1

# data.loc[data.history1 == 'mainstream', 'history1'] = 10
# data.loc[data.history1 == 'newcomer', 'history1'] = 5
# data['history1'] = data['history1'].fillna(1)

# data.loc[data.history2 == 'mainstream', 'history2'] = 10
# data.loc[data.history2 == 'newcomer', 'history2'] = 5
# data['history2'] = data['history2'].fillna(1)

# data.loc[data.history3 == 'mainstream', 'history3'] = 10
# data.loc[data.history3 == 'newcomer', 'history3'] = 5
# data['history3'] = data['history3'].fillna(1)

# print(data)

# %%
# week1.rename(columns={"stream_category": "stream1"}, inplace=True)
# week2.rename(columns={"stream_category": "stream2"}, inplace=True)
# week3.rename(columns={"stream_category": "stream3"}, inplace=True)
# week4.rename(columns={"stream_category": "stream4"}, inplace=True)
# week5.rename(columns={"stream_category": "stream5"}, inplace=True)
# week6.rename(columns={"stream_category": "stream6"}, inplace=True)
# week7.rename(columns={"stream_category": "stream7"}, inplace=True)
# week8.rename(columns={"stream_category": "stream8"}, inplace=True)
# week9.rename(columns={"stream_category": "stream9"}, inplace=True)
# week10.rename(columns={"stream_category": "stream10"}, inplace=True)

# data = pd.merge(data, week1[['title', 'stream1']], how='left', on=['title'])
# data = pd.merge(data, week2[['title', 'stream2']], how='left', on=['title'])
# data = pd.merge(data, week3[['title', 'stream3']], how='left', on=['title'])
# data = pd.merge(data, week4[['title', 'stream4']], how='left', on=['title'])
# data = pd.merge(data, week5[['title', 'stream5']], how='left', on=['title'])
# data = pd.merge(data, week6[['title', 'stream6']], how='left', on=['title'])
# data = pd.merge(data, week7[['title', 'stream7']], how='left', on=['title'])
# data = pd.merge(data, week8[['title', 'stream8']], how='left', on=['title'])
# data = pd.merge(data, week9[['title', 'stream9']], how='left', on=['title'])
# data = pd.merge(data, week10[['title', 'stream10']], how='left', on=['title'])

# print(data)

# %%
# data = data.drop(columns=['artist1', 'artist2', 'artist3', 'popularity']) # 'title', 'artist/s', 
# data = data.drop(columns=['mode', 'time_signature'])
# print(data)

# %%
# print(data.dtypes)

# %%
# # make label_category int (should be no issue because no null)
# data = data.astype({'label_category':'int'})
# # make key and duration float bc not ordinal
# data = data.astype({'key':'float'})
# data = data.astype({'duration_ms':'float'})

# %%
# print(data.dtypes)

# %%
# # split data
# data = data.drop(columns=['title', 'artist/s'])
# X_data =  data.values[:,:-1]
# y_data = data.values[:,-1]

# print(X_data.shape)
# print(y_data.shape)

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

# print("X_train: ", X_train.shape)
# print("y_train: ", y_train.shape)
# print("X_test: ", X_test.shape)
# print("y_test: ", y_test.shape)

# %%
# # normalizing (read that z-scaling is standardscaler)
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# def compute_RMSE(predictions, actual):
#     return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
# def compute_mae(predictions, actual):
#     mae = np.absolute(np.subtract(actual, predictions)).mean()
#     return mae

# %%
# X_train

# %%
# y_train

# %%
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#  RandomForestClassifier?

# %%
rfc = RandomForestClassifier()
rfc.get_params()

# %%
hyperparameters = [
        {
        'n_estimators' : [50, 100, 200, 400, 600, 800, 1000, 1200, 1600, 1800],
        'max_depth' : [10, 30, 50, 100, 150, 200, 250, 300, 350, None],
        'min_samples_split' : [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes' : [100, 300, 500, 700, 900, 1100, 1300, None]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsrfc = RandomizedSearchCV(rfc, hyperparameters, random_state=42)
rsrfc.fit(X_train, y_train)

# %%
best_params_rfc = rsrfc.best_params_
best_params_rfc

# %%
best_model_rfc = rsrfc.best_estimator_

predictions_train_rfc = best_model_rfc.predict(X_train)

train_rmse_rfc = compute_RMSE(predictions_train_rfc, y_train)
print('Training RMSE: {}'.format(train_rmse_rfc))

train_mae_rfc = compute_mae(predictions_train_rfc, y_train)
print('Training MAE: {}'.format(train_mae_rfc))

train_acc = compute_accuracy(predictions_train_rfc, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_rfc = best_model_rfc.predict(X_test)

test_rmse_rfc = compute_RMSE(predictions_test_rfc, y_test)
print('Test RMSE: {}'.format(test_rmse_rfc))

test_mae_rfc = compute_mae(predictions_test_rfc, y_test)
print('Test MAE: {}'.format(test_mae_rfc))

test_acc = compute_accuracy(predictions_test_rfc, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# SVM

# %%
from sklearn.svm import SVC

# %%
SVC?

# %%
svm = SVC()
svm.get_params()

# %%
hyperparameters = [
        {
        'C' : [0.1, 1, 100, 1000],
        'kernel' : ['rbf', 'poly', 'sigmoid', 'linear'],
        'degree' : [1, 2, 3, 4, 5, 6]
    }
]

# %%
# from sklearn.model_selection import RandomizedSearchCV
rssvm = RandomizedSearchCV(svm, hyperparameters, random_state=42)
rssvm.fit(X_train, y_train)

# %%
best_params_svm = rssvm.best_params_
best_params_svm

# %%
best_model_svm = rssvm.best_estimator_

predictions_train_svm = best_model_svm.predict(X_train)

train_rmse_svm = compute_RMSE(predictions_train_svm, y_train)
print('Training RMSE: {}'.format(train_rmse_svm))

train_mae_svm = compute_mae(predictions_train_svm, y_train)
print('Training MAE: {}'.format(train_mae_svm))

train_acc = compute_accuracy(predictions_train_svm, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_svm = best_model_svm.predict(X_test)

test_rmse_svm = compute_RMSE(predictions_test_svm, y_test)
print('Test RMSE: {}'.format(test_rmse_svm))

test_mae_svm = compute_mae(predictions_test_svm, y_test)
print('Test MAE: {}'.format(test_mae_svm))

test_acc = compute_accuracy(predictions_test_svm, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# BINARY TREES

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier?

# %%
dt = DecisionTreeClassifier()
dt.get_params()

# %%
hyperparameters = [
    {
        'min_impurity_decrease': [0.001, 0.01, 0.05, 0.1, 0.3, 0.5],
        'max_depth': [5, 10, 20, 30],
        'min_samples_split': [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes': [3, 5, 10, 20, 50, 100]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsdt = RandomizedSearchCV(dt, hyperparameters, cv=5, random_state=42, n_iter=50)
rsdt.fit(X_train, y_train)

# %%
best_params_dt = rsdt.best_params_
best_params_dt

# %%
best_model_dt = rsdt.best_estimator_

predictions_train_dt = best_model_dt.predict(X_train)

train_rmse_dt = compute_RMSE(predictions_train_dt, y_train)
print('Training RMSE: {}'.format(train_rmse_dt))

train_mae_dt = compute_mae(predictions_train_dt, y_train)
print('Training MAE: {}'.format(train_mae_dt))

train_acc_dt = compute_accuracy(predictions_train_dt, y_train)
print('Training Accuracy: {}'.format(train_acc_dt))

predictions_test_dt = best_model_dt.predict(X_test)

test_rmse_dt = compute_RMSE(predictions_test_dt, y_test)
print('Test RMSE: {}'.format(test_rmse_dt))

test_mae_dt = compute_mae(predictions_test_dt, y_test)
print('Test MAE: {}'.format(test_mae_dt))

test_acc_dt = compute_accuracy(predictions_test_dt, y_test)
print('Test Accuracy: {}'.format(test_acc_dt))

# %% [markdown]
# EXTRINSIC ONLY 3 MODELS

# %%
# split data
data = data2
data = data.drop(columns=['song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist'])
data = data.drop(columns=['danceability', 'key', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms'])
# data = data.drop(columns=['music_label', 'artist_collab', 'chart_history', 'mean_trends'])
X_data =  data.values[:,:-1]
y_data = data.values[:,-1]

print(X_data.shape)
print(y_data.shape)


# mod = """
# chart_success =~ stream1 + stream2 + stream3 + stream4 + stream5 + stream6 + stream6 + stream7 + stream8 + stream9 + stream_category
# intrinsic =~ danceability + key + loudness + speechiness + liveness + valence + tempo + duration_ms
# extrinsic =~ music_label + artist_collab + chart_history + mean_trends
# crowdsource =~ song_familiarity + artist_familiarity + bad_good + distasteful_tasty + dull_exciting + tasteless_tasteful + unimaginative_creative + untalented_talented + unpleasant_pleasant + forgettable_memorable + boring_interesting + listen_similar + share_friends + add_playlist

# chart_success ~ intrinsic + extrinsic + crowdsource

# DEFINE(ordinal) key music_label artist_collab stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
#       """
# # try normalizing non-ordinal variables
# from sklearn.preprocessing import StandardScaler
# cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 
#                 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']
# data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])
# # print(data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)

# %%
# print(X_train)

# %%
# y_train

# %%
# normalizing (read that z-scaling is standardscaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# #convert y values to categorical values
# lab = preprocessing.LabelEncoder()
# y_transformed = lab.fit_transform(y)

# %%
def compute_RMSE(predictions, actual):
    return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
def compute_mae(predictions, actual):
    mae = np.absolute(np.subtract(actual, predictions)).mean()
    return mae
def compute_accuracy(predictions, actual):
    # write code here
    num_correct = np.sum(predictions == actual)
    accuracy = num_correct/len(actual)
    return accuracy*100

# %%
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#  RandomForestClassifier?

# %%
rfc = RandomForestClassifier()
rfc.get_params()

# %%
hyperparameters = [
        {
        'n_estimators' : [50, 100, 200, 400, 600, 800, 1000, 1200, 1600, 1800],
        'max_depth' : [10, 30, 50, 100, 150, 200, 250, 300, 350, None],
        'min_samples_split' : [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes' : [100, 300, 500, 700, 900, 1100, 1300, None]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsrfc = RandomizedSearchCV(rfc, hyperparameters, random_state=42)
rsrfc.fit(X_train, y_train)

# %%
best_params_rfc = rsrfc.best_params_
best_params_rfc

# %%
best_model_rfc = rsrfc.best_estimator_

predictions_train_rfc = best_model_rfc.predict(X_train)

train_rmse_rfc = compute_RMSE(predictions_train_rfc, y_train)
print('Training RMSE: {}'.format(train_rmse_rfc))

train_mae_rfc = compute_mae(predictions_train_rfc, y_train)
print('Training MAE: {}'.format(train_mae_rfc))

train_acc = compute_accuracy(predictions_train_rfc, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_rfc = best_model_rfc.predict(X_test)

test_rmse_rfc = compute_RMSE(predictions_test_rfc, y_test)
print('Test RMSE: {}'.format(test_rmse_rfc))

test_mae_rfc = compute_mae(predictions_test_rfc, y_test)
print('Test MAE: {}'.format(test_mae_rfc))

test_acc = compute_accuracy(predictions_test_rfc, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# SVM

# %%
from sklearn.svm import SVC

# %%
SVC?

# %%
svm = SVC()
svm.get_params()

# %%
hyperparameters = [
        {
        'C' : [0.1, 1, 100, 1000],
        'kernel' : ['rbf', 'poly', 'sigmoid', 'linear'],
        'degree' : [1, 2, 3, 4, 5, 6]
    }
]

# %%
# from sklearn.model_selection import RandomizedSearchCV
rssvm = RandomizedSearchCV(svm, hyperparameters, random_state=42)
rssvm.fit(X_train, y_train)

# %%
best_params_svm = rssvm.best_params_
best_params_svm

# %%
best_model_svm = rssvm.best_estimator_

predictions_train_svm = best_model_svm.predict(X_train)

train_rmse_svm = compute_RMSE(predictions_train_svm, y_train)
print('Training RMSE: {}'.format(train_rmse_svm))

train_mae_svm = compute_mae(predictions_train_svm, y_train)
print('Training MAE: {}'.format(train_mae_svm))

train_acc = compute_accuracy(predictions_train_svm, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_svm = best_model_svm.predict(X_test)

test_rmse_svm = compute_RMSE(predictions_test_svm, y_test)
print('Test RMSE: {}'.format(test_rmse_svm))

test_mae_svm = compute_mae(predictions_test_svm, y_test)
print('Test MAE: {}'.format(test_mae_svm))

test_acc = compute_accuracy(predictions_test_svm, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# BINARY TREES

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier?

# %%
dt = DecisionTreeClassifier()
dt.get_params()

# %%
hyperparameters = [
    {
        'min_impurity_decrease': [0.001, 0.01, 0.05, 0.1, 0.3, 0.5],
        'max_depth': [5, 10, 20, 30],
        'min_samples_split': [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes': [3, 5, 10, 20, 50, 100]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsdt = RandomizedSearchCV(dt, hyperparameters, cv=5, random_state=42, n_iter=50)
rsdt.fit(X_train, y_train)

# %%
best_params_dt = rsdt.best_params_
best_params_dt

# %%
best_model_dt = rsdt.best_estimator_

predictions_train_dt = best_model_dt.predict(X_train)

train_rmse_dt = compute_RMSE(predictions_train_dt, y_train)
print('Training RMSE: {}'.format(train_rmse_dt))

train_mae_dt = compute_mae(predictions_train_dt, y_train)
print('Training MAE: {}'.format(train_mae_dt))

train_acc_dt = compute_accuracy(predictions_train_dt, y_train)
print('Training Accuracy: {}'.format(train_acc_dt))

predictions_test_dt = best_model_dt.predict(X_test)

test_rmse_dt = compute_RMSE(predictions_test_dt, y_test)
print('Test RMSE: {}'.format(test_rmse_dt))

test_mae_dt = compute_mae(predictions_test_dt, y_test)
print('Test MAE: {}'.format(test_mae_dt))

test_acc_dt = compute_accuracy(predictions_test_dt, y_test)
print('Test Accuracy: {}'.format(test_acc_dt))

# %% [markdown]
# INTRINSIC ONLY 3 MODELS

# %%
# split data
data = data2
data = data.drop(columns=['song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist'])
# data = data.drop(columns=['danceability', 'key', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms'])
data = data.drop(columns=['music_label', 'artist_collab', 'chart_history', 'mean_trends'])
X_data =  data.values[:,:-1]
y_data = data.values[:,-1]

print(X_data.shape)
print(y_data.shape)


# mod = """
# chart_success =~ stream1 + stream2 + stream3 + stream4 + stream5 + stream6 + stream6 + stream7 + stream8 + stream9 + stream_category
# intrinsic =~ danceability + key + loudness + speechiness + liveness + valence + tempo + duration_ms
# extrinsic =~ music_label + artist_collab + chart_history + mean_trends
# crowdsource =~ song_familiarity + artist_familiarity + bad_good + distasteful_tasty + dull_exciting + tasteless_tasteful + unimaginative_creative + untalented_talented + unpleasant_pleasant + forgettable_memorable + boring_interesting + listen_similar + share_friends + add_playlist

# chart_success ~ intrinsic + extrinsic + crowdsource

# DEFINE(ordinal) key music_label artist_collab stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
#       """
# # try normalizing non-ordinal variables
# from sklearn.preprocessing import StandardScaler
# cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 
#                 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']
# data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])
# # print(data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)

# %%
# print(X_train)

# %%
# y_train

# %%
# normalizing (read that z-scaling is standardscaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# #convert y values to categorical values
# lab = preprocessing.LabelEncoder()
# y_transformed = lab.fit_transform(y)

# %%
def compute_RMSE(predictions, actual):
    return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
def compute_mae(predictions, actual):
    mae = np.absolute(np.subtract(actual, predictions)).mean()
    return mae
def compute_accuracy(predictions, actual):
    # write code here
    num_correct = np.sum(predictions == actual)
    accuracy = num_correct/len(actual)
    return accuracy*100

# %%
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#  RandomForestClassifier?

# %%
rfc = RandomForestClassifier()
rfc.get_params()

# %%
hyperparameters = [
        {
        'n_estimators' : [50, 100, 200, 400, 600, 800, 1000, 1200, 1600, 1800],
        'max_depth' : [10, 30, 50, 100, 150, 200, 250, 300, 350, None],
        'min_samples_split' : [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes' : [100, 300, 500, 700, 900, 1100, 1300, None]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsrfc = RandomizedSearchCV(rfc, hyperparameters, random_state=42)
rsrfc.fit(X_train, y_train)

# %%
best_params_rfc = rsrfc.best_params_
best_params_rfc

# %%
best_model_rfc = rsrfc.best_estimator_

predictions_train_rfc = best_model_rfc.predict(X_train)

train_rmse_rfc = compute_RMSE(predictions_train_rfc, y_train)
print('Training RMSE: {}'.format(train_rmse_rfc))

train_mae_rfc = compute_mae(predictions_train_rfc, y_train)
print('Training MAE: {}'.format(train_mae_rfc))

train_acc = compute_accuracy(predictions_train_rfc, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_rfc = best_model_rfc.predict(X_test)

test_rmse_rfc = compute_RMSE(predictions_test_rfc, y_test)
print('Test RMSE: {}'.format(test_rmse_rfc))

test_mae_rfc = compute_mae(predictions_test_rfc, y_test)
print('Test MAE: {}'.format(test_mae_rfc))

test_acc = compute_accuracy(predictions_test_rfc, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# SVM

# %%
from sklearn.svm import SVC

# %%
SVC?

# %%
svm = SVC()
svm.get_params()

# %%
hyperparameters = [
        {
        'C' : [0.1, 1, 100, 1000],
        'kernel' : ['rbf', 'poly', 'sigmoid', 'linear'],
        'degree' : [1, 2, 3, 4, 5, 6]
    }
]

# %%
# from sklearn.model_selection import RandomizedSearchCV
rssvm = RandomizedSearchCV(svm, hyperparameters, random_state=42)
rssvm.fit(X_train, y_train)

# %%
best_params_svm = rssvm.best_params_
best_params_svm

# %%
best_model_svm = rssvm.best_estimator_

predictions_train_svm = best_model_svm.predict(X_train)

train_rmse_svm = compute_RMSE(predictions_train_svm, y_train)
print('Training RMSE: {}'.format(train_rmse_svm))

train_mae_svm = compute_mae(predictions_train_svm, y_train)
print('Training MAE: {}'.format(train_mae_svm))

train_acc = compute_accuracy(predictions_train_svm, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_svm = best_model_svm.predict(X_test)

test_rmse_svm = compute_RMSE(predictions_test_svm, y_test)
print('Test RMSE: {}'.format(test_rmse_svm))

test_mae_svm = compute_mae(predictions_test_svm, y_test)
print('Test MAE: {}'.format(test_mae_svm))

test_acc = compute_accuracy(predictions_test_svm, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# BINARY TREES

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier?

# %%
dt = DecisionTreeClassifier()
dt.get_params()

# %%
hyperparameters = [
    {
        'min_impurity_decrease': [0.001, 0.01, 0.05, 0.1, 0.3, 0.5],
        'max_depth': [5, 10, 20, 30],
        'min_samples_split': [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes': [3, 5, 10, 20, 50, 100]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsdt = RandomizedSearchCV(dt, hyperparameters, cv=5, random_state=42, n_iter=50)
rsdt.fit(X_train, y_train)

# %%
best_params_dt = rsdt.best_params_
best_params_dt

# %%
best_model_dt = rsdt.best_estimator_

predictions_train_dt = best_model_dt.predict(X_train)

train_rmse_dt = compute_RMSE(predictions_train_dt, y_train)
print('Training RMSE: {}'.format(train_rmse_dt))

train_mae_dt = compute_mae(predictions_train_dt, y_train)
print('Training MAE: {}'.format(train_mae_dt))

train_acc_dt = compute_accuracy(predictions_train_dt, y_train)
print('Training Accuracy: {}'.format(train_acc_dt))

predictions_test_dt = best_model_dt.predict(X_test)

test_rmse_dt = compute_RMSE(predictions_test_dt, y_test)
print('Test RMSE: {}'.format(test_rmse_dt))

test_mae_dt = compute_mae(predictions_test_dt, y_test)
print('Test MAE: {}'.format(test_mae_dt))

test_acc_dt = compute_accuracy(predictions_test_dt, y_test)
print('Test Accuracy: {}'.format(test_acc_dt))

# %% [markdown]
# CROWDSOURCE ONLY 3 MODELS

# %%
# split data
data = data2
# data = data.drop(columns=['song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist'])
data = data.drop(columns=['danceability', 'key', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms'])
data = data.drop(columns=['music_label', 'artist_collab', 'chart_history', 'mean_trends'])
X_data =  data.values[:,:-1]
y_data = data.values[:,-1]

print(X_data.shape)
print(y_data.shape)


# mod = """
# chart_success =~ stream1 + stream2 + stream3 + stream4 + stream5 + stream6 + stream6 + stream7 + stream8 + stream9 + stream_category
# intrinsic =~ danceability + key + loudness + speechiness + liveness + valence + tempo + duration_ms
# extrinsic =~ music_label + artist_collab + chart_history + mean_trends
# crowdsource =~ song_familiarity + artist_familiarity + bad_good + distasteful_tasty + dull_exciting + tasteless_tasteful + unimaginative_creative + untalented_talented + unpleasant_pleasant + forgettable_memorable + boring_interesting + listen_similar + share_friends + add_playlist

# chart_success ~ intrinsic + extrinsic + crowdsource

# DEFINE(ordinal) key music_label artist_collab stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
#       """
# # try normalizing non-ordinal variables
# from sklearn.preprocessing import StandardScaler
# cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 
#                 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']
# data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])
# # print(data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)

# %%
# print(X_train)

# %%
# y_train

# %%
# normalizing (read that z-scaling is standardscaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# #convert y values to categorical values
# lab = preprocessing.LabelEncoder()
# y_transformed = lab.fit_transform(y)

# %%
def compute_RMSE(predictions, actual):
    return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
def compute_mae(predictions, actual):
    mae = np.absolute(np.subtract(actual, predictions)).mean()
    return mae
def compute_accuracy(predictions, actual):
    # write code here
    num_correct = np.sum(predictions == actual)
    accuracy = num_correct/len(actual)
    return accuracy*100

# %%
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#  RandomForestClassifier?

# %%
rfc = RandomForestClassifier()
rfc.get_params()

# %%
hyperparameters = [
        {
        'n_estimators' : [50, 100, 200, 400, 600, 800, 1000, 1200, 1600, 1800],
        'max_depth' : [10, 30, 50, 100, 150, 200, 250, 300, 350, None],
        'min_samples_split' : [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes' : [100, 300, 500, 700, 900, 1100, 1300, None]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsrfc = RandomizedSearchCV(rfc, hyperparameters, random_state=42)
rsrfc.fit(X_train, y_train)

# %%
best_params_rfc = rsrfc.best_params_
best_params_rfc

# %%
best_model_rfc = rsrfc.best_estimator_

predictions_train_rfc = best_model_rfc.predict(X_train)

train_rmse_rfc = compute_RMSE(predictions_train_rfc, y_train)
print('Training RMSE: {}'.format(train_rmse_rfc))

train_mae_rfc = compute_mae(predictions_train_rfc, y_train)
print('Training MAE: {}'.format(train_mae_rfc))

train_acc = compute_accuracy(predictions_train_rfc, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_rfc = best_model_rfc.predict(X_test)

test_rmse_rfc = compute_RMSE(predictions_test_rfc, y_test)
print('Test RMSE: {}'.format(test_rmse_rfc))

test_mae_rfc = compute_mae(predictions_test_rfc, y_test)
print('Test MAE: {}'.format(test_mae_rfc))

test_acc = compute_accuracy(predictions_test_rfc, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# SVM

# %%
from sklearn.svm import SVC

# %%
SVC?

# %%
svm = SVC()
svm.get_params()

# %%
hyperparameters = [
        {
        'C' : [0.1, 1, 100, 1000],
        'kernel' : ['rbf', 'poly', 'sigmoid', 'linear'],
        'degree' : [1, 2, 3, 4, 5, 6]
    }
]

# %%
# from sklearn.model_selection import RandomizedSearchCV
rssvm = RandomizedSearchCV(svm, hyperparameters, random_state=42)
rssvm.fit(X_train, y_train)

# %%
best_params_svm = rssvm.best_params_
best_params_svm

# %%
best_model_svm = rssvm.best_estimator_

predictions_train_svm = best_model_svm.predict(X_train)

train_rmse_svm = compute_RMSE(predictions_train_svm, y_train)
print('Training RMSE: {}'.format(train_rmse_svm))

train_mae_svm = compute_mae(predictions_train_svm, y_train)
print('Training MAE: {}'.format(train_mae_svm))

train_acc = compute_accuracy(predictions_train_svm, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_svm = best_model_svm.predict(X_test)

test_rmse_svm = compute_RMSE(predictions_test_svm, y_test)
print('Test RMSE: {}'.format(test_rmse_svm))

test_mae_svm = compute_mae(predictions_test_svm, y_test)
print('Test MAE: {}'.format(test_mae_svm))

test_acc = compute_accuracy(predictions_test_svm, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# BINARY TREES

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier?

# %%
dt = DecisionTreeClassifier()
dt.get_params()

# %%
hyperparameters = [
    {
        'min_impurity_decrease': [0.001, 0.01, 0.05, 0.1, 0.3, 0.5],
        'max_depth': [5, 10, 20, 30],
        'min_samples_split': [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes': [3, 5, 10, 20, 50, 100]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsdt = RandomizedSearchCV(dt, hyperparameters, cv=5, random_state=42, n_iter=50)
rsdt.fit(X_train, y_train)

# %%
best_params_dt = rsdt.best_params_
best_params_dt

# %%
best_model_dt = rsdt.best_estimator_

predictions_train_dt = best_model_dt.predict(X_train)

train_rmse_dt = compute_RMSE(predictions_train_dt, y_train)
print('Training RMSE: {}'.format(train_rmse_dt))

train_mae_dt = compute_mae(predictions_train_dt, y_train)
print('Training MAE: {}'.format(train_mae_dt))

train_acc_dt = compute_accuracy(predictions_train_dt, y_train)
print('Training Accuracy: {}'.format(train_acc_dt))

predictions_test_dt = best_model_dt.predict(X_test)

test_rmse_dt = compute_RMSE(predictions_test_dt, y_test)
print('Test RMSE: {}'.format(test_rmse_dt))

test_mae_dt = compute_mae(predictions_test_dt, y_test)
print('Test MAE: {}'.format(test_mae_dt))

test_acc_dt = compute_accuracy(predictions_test_dt, y_test)
print('Test Accuracy: {}'.format(test_acc_dt))

# %% [markdown]
# BEST FEATURES FROM SEM 3 MODELS

# %%
# split data
data = data2
data = data.drop(columns=['song_familiarity', 'bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist'])
data = data.drop(columns=['danceability', 'loudness', 'speechiness', 'valence', 'duration_ms'])
data = data.drop(columns=['music_label', 'artist_collab'])
X_data =  data.values[:,:-1]
y_data = data.values[:,-1]

print(X_data.shape)
print(y_data.shape)


# mod = """
# chart_success =~ stream1 + stream2 + stream3 + stream4 + stream5 + stream6 + stream6 + stream7 + stream8 + stream9 + stream_category
# intrinsic =~ danceability + key + loudness + speechiness + liveness + valence + tempo + duration_ms
# extrinsic =~ music_label + artist_collab + chart_history + mean_trends
# crowdsource =~ song_familiarity + artist_familiarity + bad_good + distasteful_tasty + dull_exciting + tasteless_tasteful + unimaginative_creative + untalented_talented + unpleasant_pleasant + forgettable_memorable + boring_interesting + listen_similar + share_friends + add_playlist

# chart_success ~ intrinsic + extrinsic + crowdsource

# DEFINE(ordinal) key music_label artist_collab stream1 stream2 stream3 stream4 stream5 stream6 stream7 stream8 stream9 stream_category
#       """
# # try normalizing non-ordinal variables
# from sklearn.preprocessing import StandardScaler
# cols_to_norm = ['danceability', 'loudness', 'speechiness', 'liveness', 'valence', 'tempo', 'duration_ms', 'chart_history', 'mean_trends', 'song_familiarity', 'artist_familiarity', 'bad_good', 'distasteful_tasty', 
#                 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting', 'listen_similar', 'share_friends', 'add_playlist']
# data[cols_to_norm] = StandardScaler().fit_transform(data[cols_to_norm])
# # print(data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, random_state=1)

print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)

# %%
# print(X_train)

# %%
# y_train

# %%
# normalizing (read that z-scaling is standardscaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test) #why only transform? saw this sa intsy mp

# %%
# #convert y values to categorical values
# lab = preprocessing.LabelEncoder()
# y_transformed = lab.fit_transform(y)

# %%
def compute_RMSE(predictions, actual):
    return np.sqrt(np.square(np.subtract(actual, predictions)).mean())
def compute_mae(predictions, actual):
    mae = np.absolute(np.subtract(actual, predictions)).mean()
    return mae
def compute_accuracy(predictions, actual):
    # write code here
    num_correct = np.sum(predictions == actual)
    accuracy = num_correct/len(actual)
    return accuracy*100

# %%
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#  RandomForestClassifier?

# %%
rfc = RandomForestClassifier()
rfc.get_params()

# %%
hyperparameters = [
        {
        'n_estimators' : [50, 100, 200, 400, 600, 800, 1000, 1200, 1600, 1800],
        'max_depth' : [10, 30, 50, 100, 150, 200, 250, 300, 350, None],
        'min_samples_split' : [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes' : [100, 300, 500, 700, 900, 1100, 1300, None]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsrfc = RandomizedSearchCV(rfc, hyperparameters, random_state=42)
rsrfc.fit(X_train, y_train)

# %%
best_params_rfc = rsrfc.best_params_
best_params_rfc

# %%
best_model_rfc = rsrfc.best_estimator_

predictions_train_rfc = best_model_rfc.predict(X_train)

train_rmse_rfc = compute_RMSE(predictions_train_rfc, y_train)
print('Training RMSE: {}'.format(train_rmse_rfc))

train_mae_rfc = compute_mae(predictions_train_rfc, y_train)
print('Training MAE: {}'.format(train_mae_rfc))

train_acc = compute_accuracy(predictions_train_rfc, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_rfc = best_model_rfc.predict(X_test)

test_rmse_rfc = compute_RMSE(predictions_test_rfc, y_test)
print('Test RMSE: {}'.format(test_rmse_rfc))

test_mae_rfc = compute_mae(predictions_test_rfc, y_test)
print('Test MAE: {}'.format(test_mae_rfc))

test_acc = compute_accuracy(predictions_test_rfc, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# SVM

# %%
from sklearn.svm import SVC

# %%
SVC?

# %%
svm = SVC()
svm.get_params()

# %%
hyperparameters = [
        {
        'C' : [0.1, 1, 100, 1000],
        'kernel' : ['rbf', 'poly', 'sigmoid', 'linear'],
        'degree' : [1, 2, 3, 4, 5, 6]
    }
]

# %%
# from sklearn.model_selection import RandomizedSearchCV
rssvm = RandomizedSearchCV(svm, hyperparameters, random_state=42)
rssvm.fit(X_train, y_train)

# %%
best_params_svm = rssvm.best_params_
best_params_svm

# %%
best_model_svm = rssvm.best_estimator_

predictions_train_svm = best_model_svm.predict(X_train)

train_rmse_svm = compute_RMSE(predictions_train_svm, y_train)
print('Training RMSE: {}'.format(train_rmse_svm))

train_mae_svm = compute_mae(predictions_train_svm, y_train)
print('Training MAE: {}'.format(train_mae_svm))

train_acc = compute_accuracy(predictions_train_svm, y_train)
print('Training Accuracy: {}'.format(train_acc))

predictions_test_svm = best_model_svm.predict(X_test)

test_rmse_svm = compute_RMSE(predictions_test_svm, y_test)
print('Test RMSE: {}'.format(test_rmse_svm))

test_mae_svm = compute_mae(predictions_test_svm, y_test)
print('Test MAE: {}'.format(test_mae_svm))

test_acc = compute_accuracy(predictions_test_svm, y_test)
print('Test Accuracy: {}'.format(test_acc))

# %%
# BINARY TREES

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DecisionTreeClassifier?

# %%
dt = DecisionTreeClassifier()
dt.get_params()

# %%
hyperparameters = [
    {
        'min_impurity_decrease': [0.001, 0.01, 0.05, 0.1, 0.3, 0.5],
        'max_depth': [5, 10, 20, 30],
        'min_samples_split': [2, 4, 6, 10, 15, 20],
        'max_leaf_nodes': [3, 5, 10, 20, 50, 100]
    }
]

# %%
from sklearn.model_selection import RandomizedSearchCV
rsdt = RandomizedSearchCV(dt, hyperparameters, cv=5, random_state=42, n_iter=50)
rsdt.fit(X_train, y_train)

# %%
best_params_dt = rsdt.best_params_
best_params_dt

# %%
best_model_dt = rsdt.best_estimator_

predictions_train_dt = best_model_dt.predict(X_train)

train_rmse_dt = compute_RMSE(predictions_train_dt, y_train)
print('Training RMSE: {}'.format(train_rmse_dt))

train_mae_dt = compute_mae(predictions_train_dt, y_train)
print('Training MAE: {}'.format(train_mae_dt))

train_acc_dt = compute_accuracy(predictions_train_dt, y_train)
print('Training Accuracy: {}'.format(train_acc_dt))

predictions_test_dt = best_model_dt.predict(X_test)

test_rmse_dt = compute_RMSE(predictions_test_dt, y_test)
print('Test RMSE: {}'.format(test_rmse_dt))

test_mae_dt = compute_mae(predictions_test_dt, y_test)
print('Test MAE: {}'.format(test_mae_dt))

test_acc_dt = compute_accuracy(predictions_test_dt, y_test)
print('Test Accuracy: {}'.format(test_acc_dt))

# %%
# TEST SVM USING KAGGLE DATA

# %%
from sklearn.datasets import load_wine
wine = load_wine()

# %%
import pandas as pd
features = pd.DataFrame(data=wine['data'],columns=wine['feature_names'])
features.head()

# %%
print(wine)

# %%
print(wine.DESCR)

# %%
X = wine.data
y = wine.target
features = wine.feature_names
print(len(features))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
for i in range(13):
  sns.boxplot(x=y,y=X[:,i])
  plt.ylabel(features[i])
  plt.show()

# %%
for i in range(13):
  plt.hist(X[:,i],edgecolor='black')
  plt.title(features[i])
  plt.show()

# %%
target_name = wine.target_names
print(target_name)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=32)

# %%
svm = SVC()
svm.fit(X_train,y_train)
svm.score(X_test,y_test)

# %%
# GRID SEARCH (FROM KAGGLE https://www.kaggle.com/code/aniketyadav1/svm-and-hyper-parameter-tuning)

from sklearn.model_selection import GridSearchCV

param_grid = { 'C':[0.1,1,100,1000],'kernel':['rbf','poly','sigmoid','linear'],'degree':[1,2,3,4,5,6]}
grid = GridSearchCV(SVC(),param_grid)
grid.fit(X_train,y_train)

# %%
print(grid.best_params_)
print(grid.score(X_test,y_test))

# %%
svm = SVC()
svm.get_params()

# %%
hyperparameters = [
        {
        'C' : [0.1, 1, 100, 1000],
        'kernel' : ['rbf', 'poly', 'sigmoid', 'linear'],
        'degree' : [1, 2, 3, 4, 5, 6]
    }
]

# %%
rssvm = RandomizedSearchCV(svm, hyperparameters, random_state=42)
rssvm.fit(X_train, y_train)

# %%
best_params_svm = rssvm.best_params_
best_params_svm

# %%
best_model_svm = rssvm.best_estimator_

predictions_train_svm = best_model_svm.predict(X_train)

train_rmse_svm = compute_RMSE(predictions_train_svm, y_train)
print('Training RMSE: {}'.format(train_rmse_svm))

train_mae_svm = compute_mae(predictions_train_svm, y_train)
print('Training MAE: {}'.format(train_mae_svm))

predictions_test_svm = best_model_svm.predict(X_test)

test_rmse_svm = compute_RMSE(predictions_test_svm, y_test)
print('Test RMSE: {}'.format(test_rmse_svm))

test_mae_svm = compute_mae(predictions_test_svm, y_test)
print('Test MAE: {}'.format(test_mae_svm))

# %%
print(rssvm.score(X_test,y_test))
print(rssvm.score(X_test,y_test))

# %%
#split data

# %%
split = pd.read_csv('complete_data_term2run.csv', index_col=0)
split

# %%
# good song trend (week1 streamC < week10 streamC)
# bad song trend (week1 streamC >= week10 streamC)

# %%
goodTrend = split[split['stream1'] <= split['stream_category']]
goodTrend

# %%
badTrend = split[split['stream1'] > split['stream_category']]
badTrend

# %%
# 1, 5, 10 music label

# %%
musicLabel1 = split[split['music_label'] == 1]
musicLabel1

# %%
musicLabel5 = split[split['music_label'] == 5]
musicLabel5

# %%
musicLabel10 = split[split['music_label'] == 10]
musicLabel10

# %%
# with collab
# with no collab

# %%
withCollab = split[split['artist_collab'] == 1]
withCollab

# %%
noCollab = split[split['artist_collab'] == 0]
noCollab

# %%
# chart history = 72
# chart history != 72

# %%
chart72 = split[split['chart_history'] == 72]
chart72

# %%
chartNo72 = split[split['chart_history'] != 72]
chartNo72

# %%
# cancelledt
rateMean = (split[['bad_good', 'distasteful_tasty', 'dull_exciting', 'tasteless_tasteful', 'unimaginative_creative', 'untalented_talented', 'unpleasant_pleasant', 'forgettable_memorable', 'boring_interesting']].mean(axis=1)).mean()
rateMean

# %%
# low song familiarity < 4
# familiar song >= 4

# %%
lowerSongFam = split[split['song_familiarity'] < 4]
lowerSongFam

# %%
okaySongFam = split[split['song_familiarity'] >= 4]
okaySongFam

# %%
# low artist familiarity < 4
# familiar artist >= 4

# %%
lowerArtFam = split[split['artist_familiarity'] < 4]
lowerArtFam

# %%
okayArtFam = split[split['artist_familiarity'] >= 4]
okayArtFam

# %%
goodTrend.to_csv('goodTrend.csv', encoding='utf-8')
badTrend.to_csv('badTrend.csv', encoding='utf-8')
musicLabel1.to_csv('musicLabel1.csv', encoding='utf-8')
musicLabel5.to_csv('musicLabel5.csv', encoding='utf-8')
musicLabel10.to_csv('musicLabel10.csv', encoding='utf-8')
withCollab.to_csv('withCollab.csv', encoding='utf-8')
noCollab.to_csv('noCollab.csv', encoding='utf-8')
chart72.to_csv('chart72.csv', encoding='utf-8')
chartNo72.to_csv('chartNo72.csv', encoding='utf-8')
lowerSongFam.to_csv('lowerSongFam.csv', encoding='utf-8')
okaySongFam.to_csv('okaySongFam.csv', encoding='utf-8')
lowerArtFam.to_csv('lowerArtFam.csv', encoding='utf-8')
okayArtFam.to_csv('okayArtFam.csv', encoding='utf-8')
